# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.8)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.16.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import root_mean_squared_log_error
from collections import defaultdict, deque

# %%
pd.options.display.float_format = '{:.4f}'.format
pd.options.display.max_columns = None

# %% [markdown]
# # Prepare Data

# %%
data = pd.read_csv('drive/MyDrive/data/store_sales_ecuador/data.csv')
data.head()
# Out:
#          date  store_nbr      family     id  sales  onpromotion  year  month  \
# 0  2013-01-01          1  AUTOMOTIVE 0.0000 0.0000       0.0000  2013      1
# 1  2013-01-01          1   BABY CARE 1.0000 0.0000       0.0000  2013      1
# 2  2013-01-01          1      BEAUTY 2.0000 0.0000       0.0000  2013      1
# 3  2013-01-01          1   BEVERAGES 3.0000 0.0000       0.0000  2013      1
# 4  2013-01-01          1       BOOKS 4.0000 0.0000       0.0000  2013      1
#
#    day_of_week  sin_7  cos_7  sin_30.5  cos_30.5  sin_365.25  cos_365.25  \
# 0            1 0.7818 0.6235    0.2046    0.9789      0.0172      0.9999
# 1            1 0.7818 0.6235    0.2046    0.9789      0.0172      0.9999
# 2            1 0.7818 0.6235    0.2046    0.9789      0.0172      0.9999
# 3            1 0.7818 0.6235    0.2046    0.9789      0.0172      0.9999
# 4            1 0.7818 0.6235    0.2046    0.9789      0.0172      0.9999
#
#    is_payday  is_weekend  is_christmas  earthquake_effect  sales_lag_1  \
# 0          0           0             1             0.0000          NaN
# 1          0           0             1             0.0000          NaN
# 2          0           0             1             0.0000          NaN
# 3          0           0             1             0.0000          NaN
# 4          0           0             1             0.0000          NaN
#
#    sales_lag_7  sales_lag_15  sales_lag_30  sales_lag_365  \
# 0          NaN           NaN           NaN            NaN
# 1          NaN           NaN           NaN            NaN
# 2          NaN           NaN           NaN            NaN
# 3          NaN           NaN           NaN            NaN
# 4          NaN           NaN           NaN            NaN
#
#    sales_rolling_mean_30  sales_rolling_std_30  sales_rolling_mean_15  \
# 0                    NaN                   NaN                    NaN
# 1                    NaN                   NaN                    NaN
# 2                    NaN                   NaN                    NaN
# 3                    NaN                   NaN                    NaN
# 4                    NaN                   NaN                    NaN
#
#    sales_rolling_std_15  sales_rolling_median_7  sales_rolling_mean_7  \
# 0                   NaN                     NaN                   NaN
# 1                   NaN                     NaN                   NaN
# 2                   NaN                     NaN                   NaN
# 3                   NaN                     NaN                   NaN
# 4                   NaN                     NaN                   NaN
#
#   store_city store_state store_type  store_cluster holiday_locale  is_holiday  \
# 0      Quito   Pichincha          D             13       National           1
# 1      Quito   Pichincha          D             13       National           1
# 2      Quito   Pichincha          D             13       National           1
# 3      Quito   Pichincha          D             13       National           1
# 4      Quito   Pichincha          D             13       National           1
#
#    is_event  store_in_event_area  dcoilwtico  oil_lag_1  oil_lag_7  \
# 0         0                    1     93.1400        NaN        NaN
# 1         0                    1     93.1400        NaN        NaN
# 2         0                    1     93.1400        NaN        NaN
# 3         0                    1     93.1400        NaN        NaN
# 4         0                    1     93.1400        NaN        NaN
#
#    oil_lag_15  oil_lag_30  oil_lag_365  oil_rolling_mean_30  \
# 0         NaN         NaN          NaN                  NaN
# 1         NaN         NaN          NaN                  NaN
# 2         NaN         NaN          NaN                  NaN
# 3         NaN         NaN          NaN                  NaN
# 4         NaN         NaN          NaN                  NaN
#
#    oil_rolling_std_30  oil_rolling_mean_15  oil_rolling_std_15  \
# 0                 NaN                  NaN                 NaN
# 1                 NaN                  NaN                 NaN
# 2                 NaN                  NaN                 NaN
# 3                 NaN                  NaN                 NaN
# 4                 NaN                  NaN                 NaN
#
#    oil_rolling_median_7  oil_rolling_mean_7  transactions
# 0                   NaN                 NaN        0.0000
# 1                   NaN                 NaN        0.0000
# 2                   NaN                 NaN        0.0000
# 3                   NaN                 NaN        0.0000
# 4                   NaN                 NaN        0.0000

# %%
data.isnull().sum()
# Out:
# date                           0
# store_nbr                      0
# family                         0
# id                          7128
# sales                          0
# onpromotion                    0
# year                           0
# month                          0
# day_of_week                    0
# sin_7                          0
# cos_7                          0
# sin_30.5                       0
# cos_30.5                       0
# sin_365.25                     0
# cos_365.25                     0
# is_payday                      0
# is_weekend                     0
# is_christmas                   0
# earthquake_effect              0
# sales_lag_1                 1782
# sales_lag_7                12474
# sales_lag_15               26730
# sales_lag_30               53460
# sales_lag_365             659340
# sales_rolling_mean_30       1782
# sales_rolling_std_30        3564
# sales_rolling_mean_15       1782
# sales_rolling_std_15        3564
# sales_rolling_median_7      1782
# sales_rolling_mean_7        1782
# store_city                     0
# store_state                    0
# store_type                     0
# store_cluster                  0
# holiday_locale                 0
# is_holiday                     0
# is_event                       0
# store_in_event_area            0
# dcoilwtico                     0
# oil_lag_1                   1782
# oil_lag_7                  12474
# oil_lag_15                 26730
# oil_lag_30                 53460
# oil_lag_365               659340
# oil_rolling_mean_30         1782
# oil_rolling_std_30          3564
# oil_rolling_mean_15         1782
# oil_rolling_std_15          3564
# oil_rolling_median_7        1782
# oil_rolling_mean_7          1782
# transactions                   0
# dtype: int64

# %% [markdown]
# I realized that I was leaking data through lag features and rolling statistics. There are two ways to go:
#
# 1) Remove lag features and rolling statistics for 1 and 7 days - the model will predict 15 days in advance (as provided in the test sample)
# 2) Predict the model for the day ahead, add lag features and rolling statistics as the forecast progresses
#
# I choose option 2.

# %%
data['date'] = pd.to_datetime(data['date'])
end_date = data.loc[data.index[-1], 'date']
DAYS_TO_PREDICT = 15
end_of_train = end_date - pd.Timedelta(days=DAYS_TO_PREDICT)
start_valid_date = end_of_train + pd.Timedelta(days=1)
print(end_of_train)
# Out:
# 2017-07-31 00:00:00

# %% [markdown]
# Fix the data leak (we leave oil as it is - we believe that the data on future oil prices came from another model.)

# %%
data.loc[data['date'] >= end_of_train + pd.Timedelta(days=1), ['sales_lag_1']] = np.nan
data.loc[
    data['date'] >= end_of_train + pd.Timedelta(days=7),
     ['sales_lag_7', 'sales_rolling_median_7', 'sales_rolling_mean_7']] = np.nan
data[(data['family'] == 'AUTOMOTIVE') & (data['store_nbr'] == 1)  & (data['date'] > end_of_train)]
# Out:
#               date  store_nbr      family           id  sales  onpromotion  \
# 3032964 2017-08-01          1  AUTOMOTIVE 2974158.0000 5.0000       0.0000
# 3034746 2017-08-02          1  AUTOMOTIVE 2975940.0000 4.0000       0.0000
# 3036528 2017-08-03          1  AUTOMOTIVE 2977722.0000 3.0000       0.0000
# 3038310 2017-08-04          1  AUTOMOTIVE 2979504.0000 8.0000       0.0000
# 3040092 2017-08-05          1  AUTOMOTIVE 2981286.0000 5.0000       0.0000
# 3041874 2017-08-06          1  AUTOMOTIVE 2983068.0000 6.0000       0.0000
# 3043656 2017-08-07          1  AUTOMOTIVE 2984850.0000 7.0000       0.0000
# 3045438 2017-08-08          1  AUTOMOTIVE 2986632.0000 4.0000       0.0000
# 3047220 2017-08-09          1  AUTOMOTIVE 2988414.0000 7.0000       0.0000
# 3049002 2017-08-10          1  AUTOMOTIVE 2990196.0000 9.0000       0.0000
# 3050784 2017-08-11          1  AUTOMOTIVE 2991978.0000 1.0000       0.0000
# 3052566 2017-08-12          1  AUTOMOTIVE 2993760.0000 6.0000       0.0000
# 3054348 2017-08-13          1  AUTOMOTIVE 2995542.0000 1.0000       0.0000
# 3056130 2017-08-14          1  AUTOMOTIVE 2997324.0000 1.0000       0.0000
# 3057912 2017-08-15          1  AUTOMOTIVE 2999106.0000 4.0000       0.0000
#
#          year  month  day_of_week   sin_7   cos_7  sin_30.5  cos_30.5  \
# 3032964  2017      8            1  0.4339 -0.9010   -0.1028    0.9947
# 3034746  2017      8            2 -0.4339 -0.9010    0.1028    0.9947
# 3036528  2017      8            3 -0.9749 -0.2225    0.3041    0.9526
# 3038310  2017      8            4 -0.7818  0.6235    0.4925    0.8703
# 3040092  2017      8            5 -0.0000  1.0000    0.6602    0.7511
# 3041874  2017      8            6  0.7818  0.6235    0.7998    0.6002
# 3043656  2017      8            0  0.9749 -0.2225    0.9057    0.4239
# 3045438  2017      8            1  0.4339 -0.9010    0.9733    0.2297
# 3047220  2017      8            2 -0.4339 -0.9010    0.9997    0.0257
# 3049002  2017      8            3 -0.9749 -0.2225    0.9838   -0.1793
# 3050784  2017      8            4 -0.7818  0.6235    0.9263   -0.3767
# 3052566  2017      8            5 -0.0000  1.0000    0.8297   -0.5582
# 3054348  2017      8            6  0.7818  0.6235    0.6979   -0.7162
# 3056130  2017      8            0  0.9749 -0.2225    0.5367   -0.8438
# 3057912  2017      8            1  0.4339 -0.9010    0.3528   -0.9357
#
#          sin_365.25  cos_365.25  is_payday  is_weekend  is_christmas  \
# 3032964     -0.4991     -0.8666          0           0             0
# 3034746     -0.5139     -0.8578          0           0             0
# 3036528     -0.5286     -0.8489          0           0             0
# 3038310     -0.5431     -0.8397          0           0             0
# 3040092     -0.5575     -0.8302          0           1             0
# 3041874     -0.5717     -0.8205          0           1             0
# 3043656     -0.5857     -0.8105          0           0             0
# 3045438     -0.5996     -0.8003          0           0             0
# 3047220     -0.6132     -0.7899          0           0             0
# 3049002     -0.6267     -0.7792          0           0             0
# 3050784     -0.6400     -0.7683          0           0             0
# 3052566     -0.6532     -0.7572          0           1             0
# 3054348     -0.6661     -0.7459          0           1             0
# 3056130     -0.6788     -0.7343          0           0             0
# 3057912     -0.6914     -0.7225          1           0             0
#
#          earthquake_effect  sales_lag_1  sales_lag_7  sales_lag_15  \
# 3032964             0.0000          NaN      10.0000        2.0000
# 3034746             0.0000          NaN       2.0000        3.0000
# 3036528             0.0000          NaN       5.0000        7.0000
# 3038310             0.0000          NaN       7.0000        4.0000
# 3040092             0.0000          NaN       4.0000       10.0000
# 3041874             0.0000          NaN       1.0000        8.0000
# 3043656             0.0000          NaN          NaN        0.0000
# 3045438             0.0000          NaN          NaN        4.0000
# 3047220             0.0000          NaN          NaN       10.0000
# 3049002             0.0000          NaN          NaN        2.0000
# 3050784             0.0000          NaN          NaN        5.0000
# 3052566             0.0000          NaN          NaN        7.0000
# 3054348             0.0000          NaN          NaN        4.0000
# 3056130             0.0000          NaN          NaN        1.0000
# 3057912             0.0000          NaN          NaN        8.0000
#
#          sales_lag_30  sales_lag_365  sales_rolling_mean_30  \
# 3032964        4.0000         3.0000                 4.6667
# 3034746        0.0000        10.0000                 4.7000
# 3036528        5.0000         0.0000                 4.8333
# 3038310        1.0000         3.0000                 4.7667
# 3040092        5.0000         5.0000                 5.0000
# 3041874        4.0000         5.0000                 5.0000
# 3043656        6.0000         1.0000                 5.0667
# 3045438        2.0000         4.0000                 5.1000
# 3047220        3.0000         6.0000                 5.1667
# 3049002        7.0000         4.0000                 5.3000
# 3050784        7.0000         8.0000                 5.3667
# 3052566        9.0000         1.0000                 5.1667
# 3054348        4.0000         2.0000                 5.0667
# 3056130        6.0000         0.0000                 4.9667
# 3057912        2.0000         4.0000                 4.8000
#
#          sales_rolling_std_30  sales_rolling_mean_15  sales_rolling_std_15  \
# 3032964                2.8203                 5.0000                3.1848
# 3034746                2.8180                 5.2000                3.0752
# 3036528                2.6792                 5.2667                3.0347
# 3038310                2.6997                 5.0000                3.0472
# 3040092                2.6652                 5.2667                3.1275
# 3041874                2.6652                 4.9333                2.8402
# 3043656                2.6644                 4.8000                2.7308
# 3045438                2.6826                 5.2667                2.4339
# 3047220                2.6272                 5.2667                2.4339
# 3049002                2.6149                 5.0667                2.1202
# 3050784                2.6844                 5.5333                2.1668
# 3052566                2.7803                 5.2667                2.4631
# 3054348                2.6901                 5.2000                2.4260
# 3056130                2.7852                 5.0000                2.6458
# 3057912                2.8696                 5.0000                2.6458
#
#          sales_rolling_median_7  sales_rolling_mean_7 store_city store_state  \
# 3032964                  5.0000                5.2857      Quito   Pichincha
# 3034746                  5.0000                4.5714      Quito   Pichincha
# 3036528                  5.0000                4.8571      Quito   Pichincha
# 3038310                  4.0000                4.5714      Quito   Pichincha
# 3040092                  4.0000                4.7143      Quito   Pichincha
# 3041874                  5.0000                4.8571      Quito   Pichincha
# 3043656                     NaN                   NaN      Quito   Pichincha
# 3045438                     NaN                   NaN      Quito   Pichincha
# 3047220                     NaN                   NaN      Quito   Pichincha
# 3049002                     NaN                   NaN      Quito   Pichincha
# 3050784                     NaN                   NaN      Quito   Pichincha
# 3052566                     NaN                   NaN      Quito   Pichincha
# 3054348                     NaN                   NaN      Quito   Pichincha
# 3056130                     NaN                   NaN      Quito   Pichincha
# 3057912                     NaN                   NaN      Quito   Pichincha
#
#         store_type  store_cluster holiday_locale  is_holiday  is_event  \
# 3032964          D             13           NONE           0         0
# 3034746          D             13           NONE           0         0
# 3036528          D             13           NONE           0         0
# 3038310          D             13           NONE           0         0
# 3040092          D             13          Local           1         0
# 3041874          D             13           NONE           0         0
# 3043656          D             13           NONE           0         0
# 3045438          D             13           NONE           0         0
# 3047220          D             13           NONE           0         0
# 3049002          D             13       National           1         0
# 3050784          D             13       National           1         0
# 3052566          D             13           NONE           0         0
# 3054348          D             13           NONE           0         0
# 3056130          D             13           NONE           0         0
# 3057912          D             13          Local           1         0
#
#          store_in_event_area  dcoilwtico  oil_lag_1  oil_lag_7  oil_lag_15  \
# 3032964                    0     49.1900    50.2100    47.7700     46.0200
# 3034746                    0     49.6000    49.1900    48.5800     46.4000
# 3036528                    0     49.0300    49.6000    49.0500     47.1000
# 3038310                    0     49.5700    49.0300    49.7200     46.7300
# 3040092                    0     49.5700    49.5700    49.7200     45.7800
# 3041874                    0     49.5700    49.5700    49.7200     45.7800
# 3043656                    0     49.3700    49.5700    50.2100     45.7800
# 3045438                    0     49.0700    49.3700    49.1900     46.2100
# 3047220                    0     49.5900    49.0700    49.6000     47.7700
# 3049002                    1     48.5400    49.5900    49.0300     48.5800
# 3050784                    1     48.8100    48.5400    49.5700     49.0500
# 3052566                    0     48.8100    48.8100    49.5700     49.7200
# 3054348                    0     48.8100    48.8100    49.5700     49.7200
# 3056130                    0     47.5900    48.8100    49.3700     49.7200
# 3057912                    0     47.5700    47.5900    49.0700     50.2100
#
#          oil_lag_30  oil_lag_365  oil_rolling_mean_30  oil_rolling_std_30  \
# 3032964     46.0200      40.0500              46.5533              1.7222
# 3034746     46.0200      39.5000              46.6590              1.7844
# 3036528     46.0200      40.8000              46.7783              1.8584
# 3038310     45.1100      41.9200              46.8787              1.8969
# 3040092     45.5200      41.8300              47.0273              1.9280
# 3041874     44.2500      41.8300              47.1623              1.9604
# 3043656     44.2500      41.8300              47.3397              1.9282
# 3045438     44.2500      43.0600              47.5103              1.8710
# 3047220     44.4000      42.7800              47.6710              1.7864
# 3049002     45.0600      41.7500              47.8440              1.7084
# 3050784     45.4800      43.5100              47.9600              1.6291
# 3052566     46.0600      44.4700              48.0710              1.5665
# 3054348     46.5300      44.4700              48.1627              1.5247
# 3056130     46.5300      44.4700              48.2387              1.4971
# 3057912     46.5300      45.7200              48.2740              1.4676
#
#          oil_rolling_mean_15  oil_rolling_std_15  oil_rolling_median_7  \
# 3032964              47.6380              1.6941               49.7200
# 3034746              47.8493              1.6754               49.7200
# 3036528              48.0627              1.6814               49.7200
# 3038310              48.1913              1.6763               49.7200
# 3040092              48.3807              1.6598               49.6000
# 3041874              48.6333              1.5180               49.5700
# 3043656              48.8860              1.3104               49.5700
# 3045438              49.1253              0.9917               49.5700
# 3047220              49.3160              0.5811               49.5700
# 3049002              49.4373              0.3956               49.5700
# 3050784              49.4347              0.4019               49.5700
# 3052566              49.4187              0.4225               49.3700
# 3054348              49.3580              0.4411               49.0700
# 3056130              49.2973              0.4502               48.8100
# 3057912              49.1553              0.6136               48.8100
#
#          oil_rolling_mean_7  transactions
# 3032964             49.2529     1795.0000
# 3034746             49.4557     1892.0000
# 3036528             49.6014     1726.0000
# 3038310             49.5986     1847.0000
# 3040092             49.5771     1251.0000
# 3041874             49.5557      507.0000
# 3043656             49.5343     1665.0000
# 3045438             49.4143     1766.0000
# 3047220             49.3971     1766.0000
# 3049002             49.3957     1764.0000
# 3050784             49.3257      570.0000
# 3052566             49.2171     1004.0000
# 3054348             49.1086      416.0000
# 3056130             49.0000     1733.0000
# 3057912             48.7457     1693.0000

# %%
data.dtypes
# Out:
# date                      datetime64[ns]
# store_nbr                          int64
# family                            object
# id                               float64
# sales                            float64
# onpromotion                      float64
# year                               int64
# month                              int64
# day_of_week                        int64
# sin_7                            float64
# cos_7                            float64
# sin_30.5                         float64
# cos_30.5                         float64
# sin_365.25                       float64
# cos_365.25                       float64
# is_payday                          int64
# is_weekend                         int64
# is_christmas                       int64
# earthquake_effect                float64
# sales_lag_1                      float64
# sales_lag_7                      float64
# sales_lag_15                     float64
# sales_lag_30                     float64
# sales_lag_365                    float64
# sales_rolling_mean_30            float64
# sales_rolling_std_30             float64
# sales_rolling_mean_15            float64
# sales_rolling_std_15             float64
# sales_rolling_median_7           float64
# sales_rolling_mean_7             float64
# store_city                        object
# store_state                       object
# store_type                        object
# store_cluster                      int64
# holiday_locale                    object
# is_holiday                         int64
# is_event                           int64
# store_in_event_area                int64
# dcoilwtico                       float64
# oil_lag_1                        float64
# oil_lag_7                        float64
# oil_lag_15                       float64
# oil_lag_30                       float64
# oil_lag_365                      float64
# oil_rolling_mean_30              float64
# oil_rolling_std_30               float64
# oil_rolling_mean_15              float64
# oil_rolling_std_15               float64
# oil_rolling_median_7             float64
# oil_rolling_mean_7               float64
# transactions                     float64
# dtype: object

# %%
data['date'] = pd.to_datetime(data['date'])
useless_features = ['date', 'sales', 'id', 'store_nbr']
all_features = list(data.drop(columns=useless_features).columns)
cat_features = ['year', 'month', 'day_of_week',  'family', 'store_city', 'store_state', 'store_type', 'store_cluster', 'holiday_locale']
num_features = [col for col in all_features if col not in cat_features]
data[cat_features] = data[cat_features].astype('category')

# %%
data.dtypes
# Out:
# date                      datetime64[ns]
# store_nbr                          int64
# family                          category
# id                               float64
# sales                            float64
# onpromotion                      float64
# year                            category
# month                           category
# day_of_week                     category
# sin_7                            float64
# cos_7                            float64
# sin_30.5                         float64
# cos_30.5                         float64
# sin_365.25                       float64
# cos_365.25                       float64
# is_payday                          int64
# is_weekend                         int64
# is_christmas                       int64
# earthquake_effect                float64
# sales_lag_1                      float64
# sales_lag_7                      float64
# sales_lag_15                     float64
# sales_lag_30                     float64
# sales_lag_365                    float64
# sales_rolling_mean_30            float64
# sales_rolling_std_30             float64
# sales_rolling_mean_15            float64
# sales_rolling_std_15             float64
# sales_rolling_median_7           float64
# sales_rolling_mean_7             float64
# store_city                      category
# store_state                     category
# store_type                      category
# store_cluster                   category
# holiday_locale                  category
# is_holiday                         int64
# is_event                           int64
# store_in_event_area                int64
# dcoilwtico                       float64
# oil_lag_1                        float64
# oil_lag_7                        float64
# oil_lag_15                       float64
# oil_lag_30                       float64
# oil_lag_365                      float64
# oil_rolling_mean_30              float64
# oil_rolling_std_30               float64
# oil_rolling_mean_15              float64
# oil_rolling_std_15               float64
# oil_rolling_median_7             float64
# oil_rolling_mean_7               float64
# transactions                     float64
# dtype: object

# %%
train = data[data['date'] <= end_of_train]
valid = data[data['date'] > end_of_train]
valid[(valid['family'] == 'AUTOMOTIVE') & (valid['store_nbr'] == 1)]
# Out:
#               date  store_nbr      family           id  sales  onpromotion  \
# 3032964 2017-08-01          1  AUTOMOTIVE 2974158.0000 5.0000       0.0000
# 3034746 2017-08-02          1  AUTOMOTIVE 2975940.0000 4.0000       0.0000
# 3036528 2017-08-03          1  AUTOMOTIVE 2977722.0000 3.0000       0.0000
# 3038310 2017-08-04          1  AUTOMOTIVE 2979504.0000 8.0000       0.0000
# 3040092 2017-08-05          1  AUTOMOTIVE 2981286.0000 5.0000       0.0000
# 3041874 2017-08-06          1  AUTOMOTIVE 2983068.0000 6.0000       0.0000
# 3043656 2017-08-07          1  AUTOMOTIVE 2984850.0000 7.0000       0.0000
# 3045438 2017-08-08          1  AUTOMOTIVE 2986632.0000 4.0000       0.0000
# 3047220 2017-08-09          1  AUTOMOTIVE 2988414.0000 7.0000       0.0000
# 3049002 2017-08-10          1  AUTOMOTIVE 2990196.0000 9.0000       0.0000
# 3050784 2017-08-11          1  AUTOMOTIVE 2991978.0000 1.0000       0.0000
# 3052566 2017-08-12          1  AUTOMOTIVE 2993760.0000 6.0000       0.0000
# 3054348 2017-08-13          1  AUTOMOTIVE 2995542.0000 1.0000       0.0000
# 3056130 2017-08-14          1  AUTOMOTIVE 2997324.0000 1.0000       0.0000
# 3057912 2017-08-15          1  AUTOMOTIVE 2999106.0000 4.0000       0.0000
#
#          year month day_of_week   sin_7   cos_7  sin_30.5  cos_30.5  \
# 3032964  2017     8           1  0.4339 -0.9010   -0.1028    0.9947
# 3034746  2017     8           2 -0.4339 -0.9010    0.1028    0.9947
# 3036528  2017     8           3 -0.9749 -0.2225    0.3041    0.9526
# 3038310  2017     8           4 -0.7818  0.6235    0.4925    0.8703
# 3040092  2017     8           5 -0.0000  1.0000    0.6602    0.7511
# 3041874  2017     8           6  0.7818  0.6235    0.7998    0.6002
# 3043656  2017     8           0  0.9749 -0.2225    0.9057    0.4239
# 3045438  2017     8           1  0.4339 -0.9010    0.9733    0.2297
# 3047220  2017     8           2 -0.4339 -0.9010    0.9997    0.0257
# 3049002  2017     8           3 -0.9749 -0.2225    0.9838   -0.1793
# 3050784  2017     8           4 -0.7818  0.6235    0.9263   -0.3767
# 3052566  2017     8           5 -0.0000  1.0000    0.8297   -0.5582
# 3054348  2017     8           6  0.7818  0.6235    0.6979   -0.7162
# 3056130  2017     8           0  0.9749 -0.2225    0.5367   -0.8438
# 3057912  2017     8           1  0.4339 -0.9010    0.3528   -0.9357
#
#          sin_365.25  cos_365.25  is_payday  is_weekend  is_christmas  \
# 3032964     -0.4991     -0.8666          0           0             0
# 3034746     -0.5139     -0.8578          0           0             0
# 3036528     -0.5286     -0.8489          0           0             0
# 3038310     -0.5431     -0.8397          0           0             0
# 3040092     -0.5575     -0.8302          0           1             0
# 3041874     -0.5717     -0.8205          0           1             0
# 3043656     -0.5857     -0.8105          0           0             0
# 3045438     -0.5996     -0.8003          0           0             0
# 3047220     -0.6132     -0.7899          0           0             0
# 3049002     -0.6267     -0.7792          0           0             0
# 3050784     -0.6400     -0.7683          0           0             0
# 3052566     -0.6532     -0.7572          0           1             0
# 3054348     -0.6661     -0.7459          0           1             0
# 3056130     -0.6788     -0.7343          0           0             0
# 3057912     -0.6914     -0.7225          1           0             0
#
#          earthquake_effect  sales_lag_1  sales_lag_7  sales_lag_15  \
# 3032964             0.0000          NaN      10.0000        2.0000
# 3034746             0.0000          NaN       2.0000        3.0000
# 3036528             0.0000          NaN       5.0000        7.0000
# 3038310             0.0000          NaN       7.0000        4.0000
# 3040092             0.0000          NaN       4.0000       10.0000
# 3041874             0.0000          NaN       1.0000        8.0000
# 3043656             0.0000          NaN          NaN        0.0000
# 3045438             0.0000          NaN          NaN        4.0000
# 3047220             0.0000          NaN          NaN       10.0000
# 3049002             0.0000          NaN          NaN        2.0000
# 3050784             0.0000          NaN          NaN        5.0000
# 3052566             0.0000          NaN          NaN        7.0000
# 3054348             0.0000          NaN          NaN        4.0000
# 3056130             0.0000          NaN          NaN        1.0000
# 3057912             0.0000          NaN          NaN        8.0000
#
#          sales_lag_30  sales_lag_365  sales_rolling_mean_30  \
# 3032964        4.0000         3.0000                 4.6667
# 3034746        0.0000        10.0000                 4.7000
# 3036528        5.0000         0.0000                 4.8333
# 3038310        1.0000         3.0000                 4.7667
# 3040092        5.0000         5.0000                 5.0000
# 3041874        4.0000         5.0000                 5.0000
# 3043656        6.0000         1.0000                 5.0667
# 3045438        2.0000         4.0000                 5.1000
# 3047220        3.0000         6.0000                 5.1667
# 3049002        7.0000         4.0000                 5.3000
# 3050784        7.0000         8.0000                 5.3667
# 3052566        9.0000         1.0000                 5.1667
# 3054348        4.0000         2.0000                 5.0667
# 3056130        6.0000         0.0000                 4.9667
# 3057912        2.0000         4.0000                 4.8000
#
#          sales_rolling_std_30  sales_rolling_mean_15  sales_rolling_std_15  \
# 3032964                2.8203                 5.0000                3.1848
# 3034746                2.8180                 5.2000                3.0752
# 3036528                2.6792                 5.2667                3.0347
# 3038310                2.6997                 5.0000                3.0472
# 3040092                2.6652                 5.2667                3.1275
# 3041874                2.6652                 4.9333                2.8402
# 3043656                2.6644                 4.8000                2.7308
# 3045438                2.6826                 5.2667                2.4339
# 3047220                2.6272                 5.2667                2.4339
# 3049002                2.6149                 5.0667                2.1202
# 3050784                2.6844                 5.5333                2.1668
# 3052566                2.7803                 5.2667                2.4631
# 3054348                2.6901                 5.2000                2.4260
# 3056130                2.7852                 5.0000                2.6458
# 3057912                2.8696                 5.0000                2.6458
#
#          sales_rolling_median_7  sales_rolling_mean_7 store_city store_state  \
# 3032964                  5.0000                5.2857      Quito   Pichincha
# 3034746                  5.0000                4.5714      Quito   Pichincha
# 3036528                  5.0000                4.8571      Quito   Pichincha
# 3038310                  4.0000                4.5714      Quito   Pichincha
# 3040092                  4.0000                4.7143      Quito   Pichincha
# 3041874                  5.0000                4.8571      Quito   Pichincha
# 3043656                     NaN                   NaN      Quito   Pichincha
# 3045438                     NaN                   NaN      Quito   Pichincha
# 3047220                     NaN                   NaN      Quito   Pichincha
# 3049002                     NaN                   NaN      Quito   Pichincha
# 3050784                     NaN                   NaN      Quito   Pichincha
# 3052566                     NaN                   NaN      Quito   Pichincha
# 3054348                     NaN                   NaN      Quito   Pichincha
# 3056130                     NaN                   NaN      Quito   Pichincha
# 3057912                     NaN                   NaN      Quito   Pichincha
#
#         store_type store_cluster holiday_locale  is_holiday  is_event  \
# 3032964          D            13           NONE           0         0
# 3034746          D            13           NONE           0         0
# 3036528          D            13           NONE           0         0
# 3038310          D            13           NONE           0         0
# 3040092          D            13          Local           1         0
# 3041874          D            13           NONE           0         0
# 3043656          D            13           NONE           0         0
# 3045438          D            13           NONE           0         0
# 3047220          D            13           NONE           0         0
# 3049002          D            13       National           1         0
# 3050784          D            13       National           1         0
# 3052566          D            13           NONE           0         0
# 3054348          D            13           NONE           0         0
# 3056130          D            13           NONE           0         0
# 3057912          D            13          Local           1         0
#
#          store_in_event_area  dcoilwtico  oil_lag_1  oil_lag_7  oil_lag_15  \
# 3032964                    0     49.1900    50.2100    47.7700     46.0200
# 3034746                    0     49.6000    49.1900    48.5800     46.4000
# 3036528                    0     49.0300    49.6000    49.0500     47.1000
# 3038310                    0     49.5700    49.0300    49.7200     46.7300
# 3040092                    0     49.5700    49.5700    49.7200     45.7800
# 3041874                    0     49.5700    49.5700    49.7200     45.7800
# 3043656                    0     49.3700    49.5700    50.2100     45.7800
# 3045438                    0     49.0700    49.3700    49.1900     46.2100
# 3047220                    0     49.5900    49.0700    49.6000     47.7700
# 3049002                    1     48.5400    49.5900    49.0300     48.5800
# 3050784                    1     48.8100    48.5400    49.5700     49.0500
# 3052566                    0     48.8100    48.8100    49.5700     49.7200
# 3054348                    0     48.8100    48.8100    49.5700     49.7200
# 3056130                    0     47.5900    48.8100    49.3700     49.7200
# 3057912                    0     47.5700    47.5900    49.0700     50.2100
#
#          oil_lag_30  oil_lag_365  oil_rolling_mean_30  oil_rolling_std_30  \
# 3032964     46.0200      40.0500              46.5533              1.7222
# 3034746     46.0200      39.5000              46.6590              1.7844
# 3036528     46.0200      40.8000              46.7783              1.8584
# 3038310     45.1100      41.9200              46.8787              1.8969
# 3040092     45.5200      41.8300              47.0273              1.9280
# 3041874     44.2500      41.8300              47.1623              1.9604
# 3043656     44.2500      41.8300              47.3397              1.9282
# 3045438     44.2500      43.0600              47.5103              1.8710
# 3047220     44.4000      42.7800              47.6710              1.7864
# 3049002     45.0600      41.7500              47.8440              1.7084
# 3050784     45.4800      43.5100              47.9600              1.6291
# 3052566     46.0600      44.4700              48.0710              1.5665
# 3054348     46.5300      44.4700              48.1627              1.5247
# 3056130     46.5300      44.4700              48.2387              1.4971
# 3057912     46.5300      45.7200              48.2740              1.4676
#
#          oil_rolling_mean_15  oil_rolling_std_15  oil_rolling_median_7  \
# 3032964              47.6380              1.6941               49.7200
# 3034746              47.8493              1.6754               49.7200
# 3036528              48.0627              1.6814               49.7200
# 3038310              48.1913              1.6763               49.7200
# 3040092              48.3807              1.6598               49.6000
# 3041874              48.6333              1.5180               49.5700
# 3043656              48.8860              1.3104               49.5700
# 3045438              49.1253              0.9917               49.5700
# 3047220              49.3160              0.5811               49.5700
# 3049002              49.4373              0.3956               49.5700
# 3050784              49.4347              0.4019               49.5700
# 3052566              49.4187              0.4225               49.3700
# 3054348              49.3580              0.4411               49.0700
# 3056130              49.2973              0.4502               48.8100
# 3057912              49.1553              0.6136               48.8100
#
#          oil_rolling_mean_7  transactions
# 3032964             49.2529     1795.0000
# 3034746             49.4557     1892.0000
# 3036528             49.6014     1726.0000
# 3038310             49.5986     1847.0000
# 3040092             49.5771     1251.0000
# 3041874             49.5557      507.0000
# 3043656             49.5343     1665.0000
# 3045438             49.4143     1766.0000
# 3047220             49.3971     1766.0000
# 3049002             49.3957     1764.0000
# 3050784             49.3257      570.0000
# 3052566             49.2171     1004.0000
# 3054348             49.1086      416.0000
# 3056130             49.0000     1733.0000
# 3057912             48.7457     1693.0000

# %%
discrete_sales_families = []
continuous_sales_families = []
for family, group in data.groupby('family'):
  if np.allclose(group['sales'], group['sales'].astype('int')):
    discrete_sales_families.append(family)
  else:
    continuous_sales_families.append(family)

print(discrete_sales_families)
print(continuous_sales_families)
# Out:
# /tmp/ipython-input-1793903984.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for family, group in data.groupby('family'):
# ['AUTOMOTIVE', 'BABY CARE', 'BEAUTY', 'BEVERAGES', 'BOOKS', 'CELEBRATION', 'CLEANING', 'DAIRY', 'EGGS', 'GROCERY II', 'HARDWARE', 'HOME AND KITCHEN I', 'HOME AND KITCHEN II', 'HOME APPLIANCES', 'HOME CARE', 'LADIESWEAR', 'LAWN AND GARDEN', 'LINGERIE', 'LIQUOR,WINE,BEER', 'MAGAZINES', 'PERSONAL CARE', 'PET SUPPLIES', 'PLAYERS AND ELECTRONICS', 'SCHOOL AND OFFICE SUPPLIES']
# ['BREAD/BAKERY', 'DELI', 'FROZEN FOODS', 'GROCERY I', 'MEATS', 'POULTRY', 'PREPARED FOODS', 'PRODUCE', 'SEAFOOD']

# %% [markdown]
# # Approach 1 - try all data
# Yes, first I'll try to just upload all the data.

# %%
train_1 = train.copy()
valid_1 = valid.copy()
# for rolling statistics and lag features
prevalid_1_ = data[
    (data['date'] >= (end_of_train - pd.Timedelta(days=30))) &
    (data['date'] <= end_of_train)
    ].copy()

# %%
prevalid_1_.head()
# Out:
#               date  store_nbr      family           id     sales  onpromotion  \
# 2975940 2017-07-01          1  AUTOMOTIVE 2918916.0000    7.0000       0.0000
# 2975941 2017-07-01          1   BABY CARE 2918917.0000    0.0000       0.0000
# 2975942 2017-07-01          1      BEAUTY 2918918.0000    7.0000       1.0000
# 2975943 2017-07-01          1   BEVERAGES 2918919.0000 2596.0000      27.0000
# 2975944 2017-07-01          1       BOOKS 2918920.0000    0.0000       0.0000
#
#          year month day_of_week   sin_7  cos_7  sin_30.5  cos_30.5  \
# 2975940  2017     7           5 -0.0000 1.0000   -0.2046    0.9789
# 2975941  2017     7           5 -0.0000 1.0000   -0.2046    0.9789
# 2975942  2017     7           5 -0.0000 1.0000   -0.2046    0.9789
# 2975943  2017     7           5 -0.0000 1.0000   -0.2046    0.9789
# 2975944  2017     7           5 -0.0000 1.0000   -0.2046    0.9789
#
#          sin_365.25  cos_365.25  is_payday  is_weekend  is_christmas  \
# 2975940      0.0108     -0.9999          0           1             0
# 2975941      0.0108     -0.9999          0           1             0
# 2975942      0.0108     -0.9999          0           1             0
# 2975943      0.0108     -0.9999          0           1             0
# 2975944      0.0108     -0.9999          0           1             0
#
#          earthquake_effect  sales_lag_1  sales_lag_7  sales_lag_15  \
# 2975940             0.0000      11.0000      12.0000        4.0000
# 2975941             0.0000       0.0000       0.0000        0.0000
# 2975942             0.0000       2.0000       8.0000        5.0000
# 2975943             0.0000    2496.0000    2674.0000     2532.0000
# 2975944             0.0000       0.0000       1.0000        1.0000
#
#          sales_lag_30  sales_lag_365  sales_rolling_mean_30  \
# 2975940        6.0000         8.0000                 4.6000
# 2975941        0.0000         0.0000                 0.0000
# 2975942        1.0000         5.0000                 3.4000
# 2975943     2250.0000      2298.0000              2287.5667
# 2975944        3.0000         0.0000                 0.5000
#
#          sales_rolling_std_30  sales_rolling_mean_15  sales_rolling_std_15  \
# 2975940                4.0565                 4.2667                3.6541
# 2975941                0.0000                 0.0000                0.0000
# 2975942                2.0611                 4.0667                2.0166
# 2975943              528.7883              2230.6667              562.8255
# 2975944                0.9002                 0.1333                0.3519
#
#          sales_rolling_median_7  sales_rolling_mean_7 store_city store_state  \
# 2975940                  4.0000                5.2857      Quito   Pichincha
# 2975941                  0.0000                0.0000      Quito   Pichincha
# 2975942                  4.0000                4.4286      Quito   Pichincha
# 2975943               2203.0000             2130.5714      Quito   Pichincha
# 2975944                  0.0000                0.1429      Quito   Pichincha
#
#         store_type store_cluster holiday_locale  is_holiday  is_event  \
# 2975940          D            13           NONE           0         0
# 2975941          D            13           NONE           0         0
# 2975942          D            13           NONE           0         0
# 2975943          D            13           NONE           0         0
# 2975944          D            13           NONE           0         0
#
#          store_in_event_area  dcoilwtico  oil_lag_1  oil_lag_7  oil_lag_15  \
# 2975940                    0     46.0200    46.0200    42.8600     44.7300
# 2975941                    0     46.0200    46.0200    42.8600     44.7300
# 2975942                    0     46.0200    46.0200    42.8600     44.7300
# 2975943                    0     46.0200    46.0200    42.8600     44.7300
# 2975944                    0     46.0200    46.0200    42.8600     44.7300
#
#          oil_lag_30  oil_lag_365  oil_rolling_mean_30  oil_rolling_std_30  \
# 2975940     48.3200      49.0200              45.2030              1.7425
# 2975941     48.3200      49.0200              45.2030              1.7425
# 2975942     48.3200      49.0200              45.2030              1.7425
# 2975943     48.3200      49.0200              45.2030              1.7425
# 2975944     48.3200      49.0200              45.2030              1.7425
#
#          oil_rolling_mean_15  oil_rolling_std_15  oil_rolling_median_7  \
# 2975940              43.8993              1.0808               44.2500
# 2975941              43.8993              1.0808               44.2500
# 2975942              43.8993              1.0808               44.2500
# 2975943              43.8993              1.0808               44.2500
# 2975944              43.8993              1.0808               44.2500
#
#          oil_rolling_mean_7  transactions
# 2975940             44.1214     1362.0000
# 2975941             44.1214     1362.0000
# 2975942             44.1214     1362.0000
# 2975943             44.1214     1362.0000
# 2975944             44.1214     1362.0000

# %%
train_1['is_discrete'] = train_1['family'].isin(discrete_sales_families).astype('int')
valid_1['is_discrete'] = valid_1['family'].isin(discrete_sales_families).astype('int')
prevalid_1_['is_discrete'] = prevalid_1_['family'].isin(discrete_sales_families).astype('int')

# %%
X_train_1_catboost = train_1[cat_features + num_features + ['is_discrete']]
y_train_1_catboost = np.log1p(train_1['sales'])

# %%
train_pool = Pool(X_train_1_catboost, y_train_1_catboost, cat_features=cat_features)
catboost_model = CatBoostRegressor(loss_function='RMSE', random_seed=42, verbose=100, iterations=1000, task_type='GPU')
catboost_model.fit(train_pool)
# Out:
# Learning rate set to 0.115461
# 0:	learn: 2.4071142	total: 544ms	remaining: 9m 3s
# 100:	learn: 0.4128952	total: 52.8s	remaining: 7m 50s
# 200:	learn: 0.3961674	total: 1m 44s	remaining: 6m 56s
# 300:	learn: 0.3863845	total: 2m 36s	remaining: 6m 3s
# 400:	learn: 0.3803550	total: 3m 27s	remaining: 5m 9s
# 500:	learn: 0.3756789	total: 4m 19s	remaining: 4m 18s
# 600:	learn: 0.3723069	total: 5m 12s	remaining: 3m 27s
# 700:	learn: 0.3698289	total: 6m 4s	remaining: 2m 35s
# 800:	learn: 0.3674088	total: 6m 56s	remaining: 1m 43s
# 900:	learn: 0.3655992	total: 7m 48s	remaining: 51.5s
# 999:	learn: 0.3639034	total: 8m 40s	remaining: 0us

# %%
feature_importance_series = pd.Series(catboost_model.feature_importances_, index=X_train_1_catboost.columns)
feature_importance_series
# Out:
# year                      0.1716
# month                     0.1471
# day_of_week               0.7767
# family                    2.0062
# store_city                0.0690
# store_state               0.0785
# store_type                0.1316
# store_cluster             0.0638
# holiday_locale            0.0242
# onpromotion               0.8187
# sin_7                     0.0757
# cos_7                     0.0197
# sin_30.5                  0.2083
# cos_30.5                  0.6224
# sin_365.25                0.2949
# cos_365.25                0.9776
# is_payday                 0.0103
# is_weekend                0.7786
# is_christmas              4.4919
# earthquake_effect         0.0168
# sales_lag_1              12.1112
# sales_lag_7              24.2080
# sales_lag_15              3.0816
# sales_lag_30              0.2176
# sales_lag_365             0.4292
# sales_rolling_mean_30     0.4547
# sales_rolling_std_30      0.3145
# sales_rolling_mean_15     1.1208
# sales_rolling_std_15      0.2461
# sales_rolling_median_7   15.3944
# sales_rolling_mean_7     26.8028
# is_holiday                0.0440
# is_event                  0.0280
# store_in_event_area       0.1475
# dcoilwtico                0.0825
# oil_lag_1                 0.2195
# oil_lag_7                 0.0937
# oil_lag_15                0.0449
# oil_lag_30                0.1078
# oil_lag_365               0.2861
# oil_rolling_mean_30       0.0674
# oil_rolling_std_30        0.1834
# oil_rolling_mean_15       0.1001
# oil_rolling_std_15        0.1928
# oil_rolling_median_7      0.0749
# oil_rolling_mean_7        0.1024
# transactions              1.9943
# is_discrete               0.0662
# dtype: float64

# %%
print('Top 10 important features')
feature_importance_series.nlargest(10)
# Out:
# Top 10 important features
# sales_rolling_mean_7     26.8028
# sales_lag_7              24.2080
# sales_rolling_median_7   15.3944
# sales_lag_1              12.1112
# is_christmas              4.4919
# sales_lag_15              3.0816
# family                    2.0062
# transactions              1.9943
# sales_rolling_mean_15     1.1208
# cos_365.25                0.9776
# dtype: float64

# %%
print('Top 10 non-important features')
feature_importance_series.nsmallest(10)
# Out:
# Top 10 non-important features
# is_payday             0.0103
# earthquake_effect     0.0168
# cos_7                 0.0197
# holiday_locale        0.0242
# is_event              0.0280
# is_holiday            0.0440
# oil_lag_15            0.0449
# store_cluster         0.0638
# is_discrete           0.0662
# oil_rolling_mean_30   0.0674
# dtype: float64

# %%
valid_1.columns
# Out:
# Index(['date', 'store_nbr', 'family', 'id', 'sales', 'onpromotion', 'year',
#        'month', 'day_of_week', 'sin_7', 'cos_7', 'sin_30.5', 'cos_30.5',
#        'sin_365.25', 'cos_365.25', 'is_payday', 'is_weekend', 'is_christmas',
#        'earthquake_effect', 'sales_lag_1', 'sales_lag_7', 'sales_lag_15',
#        'sales_lag_30', 'sales_lag_365', 'sales_rolling_mean_30',
#        'sales_rolling_std_30', 'sales_rolling_mean_15', 'sales_rolling_std_15',
#        'sales_rolling_median_7', 'sales_rolling_mean_7', 'store_city',
#        'store_state', 'store_type', 'store_cluster', 'holiday_locale',
#        'is_holiday', 'is_event', 'store_in_event_area', 'dcoilwtico',
#        'oil_lag_1', 'oil_lag_7', 'oil_lag_15', 'oil_lag_30', 'oil_lag_365',
#        'oil_rolling_mean_30', 'oil_rolling_std_30', 'oil_rolling_mean_15',
#        'oil_rolling_std_15', 'oil_rolling_median_7', 'oil_rolling_mean_7',
#        'transactions', 'is_discrete'],
#       dtype='object')

# %%
# For each pair (store_nbr, family), we store a queue of sales (maximum of the last 30)
history = defaultdict(lambda: deque(maxlen=30))

# Filling in the history with the initial data
for _, row in prevalid_1_.iterrows():
    key = (row.store_nbr, row.family)
    history[key].append(row.sales)

common_loss = 0

for d in range(DAYS_TO_PREDICT):
    prediction_date = start_valid_date + pd.Timedelta(days=d)
    valid_today = valid_1[valid_1['date'] == prediction_date].copy()

    # we create features incrementally
    sales_lag_1 = []
    sales_lag_7 = []
    rolling_mean_30 = []
    rolling_std_30 = []
    rolling_mean_15 = []
    rolling_std_15 = []
    rolling_median_7 = []
    rolling_mean_7 = []

    for _, row in valid_today.iterrows():
        key = (row.store_nbr, row.family)
        hist = history[key]

        # Lags
        sales_lag_1.append(hist[-1] if len(hist) >= 1 else np.nan)
        sales_lag_7.append(hist[-7] if len(hist) >= 7 else np.nan)

        # Rolling
        arr = np.array(hist)
        rolling_mean_30.append(arr[-30:].mean() if len(arr) > 0 else np.nan)
        rolling_std_30.append(arr[-30:].std() if len(arr) > 0 else np.nan)
        rolling_mean_15.append(arr[-15:].mean() if len(arr) > 0 else np.nan)
        rolling_std_15.append(arr[-15:].std() if len(arr) > 0 else np.nan)
        rolling_median_7.append(np.median(arr[-7:]) if len(arr) > 0 else np.nan)
        rolling_mean_7.append(arr[-7:].mean() if len(arr) > 0 else np.nan)

    valid_today['sales_lag_1'] = sales_lag_1
    valid_today['sales_lag_7'] = sales_lag_7
    valid_today['sales_rolling_mean_30'] = rolling_mean_30
    valid_today['sales_rolling_std_30'] = rolling_std_30
    valid_today['sales_rolling_mean_15'] = rolling_mean_15
    valid_today['sales_rolling_std_15'] = rolling_std_15
    valid_today['sales_rolling_median_7'] = rolling_median_7
    valid_today['sales_rolling_mean_7'] = rolling_mean_7

    # inference
    x_valid = valid_today[cat_features + num_features + ['is_discrete']]
    y_valid = np.array(valid_today['sales'])

    y_pred_log = catboost_model.predict(x_valid)
    y_pred = np.maximum(0, np.expm1(y_pred_log))

    mask_discrete = x_valid['is_discrete'] == 1
    y_pred[mask_discrete] = np.round(y_pred[mask_discrete])

    # refresh history
    for (_, row), pred in zip(valid_today.iterrows(), y_pred):
        key = (row.store_nbr, row.family)
        history[key].append(pred)

    #loss
    loss = root_mean_squared_log_error(y_valid, y_pred)
    print(f'Loss on {prediction_date}: {loss}')
    common_loss += loss

common_loss /= DAYS_TO_PREDICT
print(f'Common loss: {common_loss}')
# Out:
# Loss on 2017-08-01 00:00:00: 0.4296370818301105
# Loss on 2017-08-02 00:00:00: 0.39664550127445813
# Loss on 2017-08-03 00:00:00: 0.3995413015792306
# Loss on 2017-08-04 00:00:00: 0.42865924571938824
# Loss on 2017-08-05 00:00:00: 0.3837154793427524
# Loss on 2017-08-06 00:00:00: 0.40943480600788096
# Loss on 2017-08-07 00:00:00: 0.4295762479517211
# Loss on 2017-08-08 00:00:00: 0.4467697406883647
# Loss on 2017-08-09 00:00:00: 0.410658268395596
# Loss on 2017-08-10 00:00:00: 0.4220397990930117
# Loss on 2017-08-11 00:00:00: 0.44449466012620065
# Loss on 2017-08-12 00:00:00: 0.41718079584543577
# Loss on 2017-08-13 00:00:00: 0.41391764783983365
# Loss on 2017-08-14 00:00:00: 0.4690524846238531
# Loss on 2017-08-15 00:00:00: 0.4596856888329694
# Common loss: 0.4240672499433872

# %%
del train_1
del valid_1
del history
del prevalid_1_
del X_train_1_catboost
del y_train_1_catboost

# %% [markdown]
# # Approach 2 - The same thing, but let's try to train only on fresh stable data from 2016.

# %%
train_2 = train[train['date'] >= '2016-01-01'].copy()
valid_2 = valid.copy()
# for rolling statistics and lag features
prevalid_2 = data[
    (data['date'] >= (end_of_train - pd.Timedelta(days=30))) &
    (data['date'] <= end_of_train)
    ].copy()

# %%
train_2.head()
# Out:
#               date  store_nbr      family           id  sales  onpromotion  \
# 1978020 2016-01-01          1  AUTOMOTIVE 1945944.0000 0.0000       0.0000
# 1978021 2016-01-01          1   BABY CARE 1945945.0000 0.0000       0.0000
# 1978022 2016-01-01          1      BEAUTY 1945946.0000 0.0000       0.0000
# 1978023 2016-01-01          1   BEVERAGES 1945947.0000 0.0000       0.0000
# 1978024 2016-01-01          1       BOOKS 1945948.0000 0.0000       0.0000
#
#          year month day_of_week  sin_7  cos_7  sin_30.5  cos_30.5  sin_365.25  \
# 1978020  2016     1           4 0.7818 0.6235    0.2046    0.9789      0.0172
# 1978021  2016     1           4 0.7818 0.6235    0.2046    0.9789      0.0172
# 1978022  2016     1           4 0.7818 0.6235    0.2046    0.9789      0.0172
# 1978023  2016     1           4 0.7818 0.6235    0.2046    0.9789      0.0172
# 1978024  2016     1           4 0.7818 0.6235    0.2046    0.9789      0.0172
#
#          cos_365.25  is_payday  is_weekend  is_christmas  earthquake_effect  \
# 1978020      0.9999          0           0             1             0.0000
# 1978021      0.9999          0           0             1             0.0000
# 1978022      0.9999          0           0             1             0.0000
# 1978023      0.9999          0           0             1             0.0000
# 1978024      0.9999          0           0             1             0.0000
#
#          sales_lag_1  sales_lag_7  sales_lag_15  sales_lag_30  sales_lag_365  \
# 1978020       5.0000       0.0000        3.0000        1.0000         0.0000
# 1978021       0.0000       0.0000        0.0000        0.0000         0.0000
# 1978022       0.0000       0.0000        5.0000        4.0000         0.0000
# 1978023    2179.0000       0.0000     1958.0000     2520.0000         0.0000
# 1978024       0.0000       0.0000        0.0000        0.0000         0.0000
#
#          sales_rolling_mean_30  sales_rolling_std_30  sales_rolling_mean_15  \
# 1978020                 4.2333                3.1914                 3.9333
# 1978021                 0.0000                0.0000                 0.0000
# 1978022                 2.6000                1.7538                 2.8000
# 1978023              2025.7000              615.2982              1914.1333
# 1978024                 0.0000                0.0000                 0.0000
#
#          sales_rolling_std_15  sales_rolling_median_7  sales_rolling_mean_7  \
# 1978020                2.8652                  5.0000                4.7143
# 1978021                0.0000                  0.0000                0.0000
# 1978022                2.0424                  0.0000                1.5714
# 1978023              752.8484               1842.0000             1562.4286
# 1978024                0.0000                  0.0000                0.0000
#
#         store_city store_state store_type store_cluster holiday_locale  \
# 1978020      Quito   Pichincha          D            13       National
# 1978021      Quito   Pichincha          D            13       National
# 1978022      Quito   Pichincha          D            13       National
# 1978023      Quito   Pichincha          D            13       National
# 1978024      Quito   Pichincha          D            13       National
#
#          is_holiday  is_event  store_in_event_area  dcoilwtico  oil_lag_1  \
# 1978020           1         0                    1     37.1300    37.1300
# 1978021           1         0                    1     37.1300    37.1300
# 1978022           1         0                    1     37.1300    37.1300
# 1978023           1         0                    1     37.1300    37.1300
# 1978024           1         0                    1     37.1300    37.1300
#
#          oil_lag_7  oil_lag_15  oil_lag_30  oil_lag_365  oil_rolling_mean_30  \
# 1978020    37.6200     34.9800     39.9300      53.4500              37.0390
# 1978021    37.6200     34.9800     39.9300      53.4500              37.0390
# 1978022    37.6200     34.9800     39.9300      53.4500              37.0390
# 1978023    37.6200     34.9800     39.9300      53.4500              37.0390
# 1978024    37.6200     34.9800     39.9300      53.4500              37.0390
#
#          oil_rolling_std_30  oil_rolling_mean_15  oil_rolling_std_15  \
# 1978020              1.7661              36.3340              1.2751
# 1978021              1.7661              36.3340              1.2751
# 1978022              1.7661              36.3340              1.2751
# 1978023              1.7661              36.3340              1.2751
# 1978024              1.7661              36.3340              1.2751
#
#          oil_rolling_median_7  oil_rolling_mean_7  transactions
# 1978020               37.6200             37.2600        0.0000
# 1978021               37.6200             37.2600        0.0000
# 1978022               37.6200             37.2600        0.0000
# 1978023               37.6200             37.2600        0.0000
# 1978024               37.6200             37.2600        0.0000

# %%
train_2.shape
# Out:
# (1054944, 51)

# %%
train_2['is_discrete'] = train_2['family'].isin(discrete_sales_families).astype('int')
valid_2['is_discrete'] = valid_2['family'].isin(discrete_sales_families).astype('int')
prevalid_2['is_discrete'] = prevalid_2['family'].isin(discrete_sales_families).astype('int')

# %%
X_train_2_catboost = train_2[cat_features + num_features + ['is_discrete']]
y_train_2_catboost = np.log1p(train_2['sales'])

# %%
train_pool = Pool(X_train_2_catboost, y_train_2_catboost, cat_features=cat_features)
catboost_model_2 = CatBoostRegressor(loss_function='RMSE', random_seed=42, verbose=100, iterations=1000, task_type='GPU')
catboost_model_2.fit(train_pool)
# Out:
# Learning rate set to 0.100544
# 0:	learn: 2.3439333	total: 169ms	remaining: 2m 48s
# 100:	learn: 0.4179238	total: 15.4s	remaining: 2m 17s
# 200:	learn: 0.4050282	total: 31.6s	remaining: 2m 5s
# 300:	learn: 0.3982596	total: 48.1s	remaining: 1m 51s
# 400:	learn: 0.3940286	total: 1m 5s	remaining: 1m 37s
# 500:	learn: 0.3902812	total: 1m 20s	remaining: 1m 20s
# 600:	learn: 0.3876228	total: 1m 34s	remaining: 1m 2s
# 700:	learn: 0.3854915	total: 1m 49s	remaining: 46.6s
# 800:	learn: 0.3839523	total: 2m 3s	remaining: 30.8s
# 900:	learn: 0.3825152	total: 2m 18s	remaining: 15.2s
# 999:	learn: 0.3811594	total: 2m 34s	remaining: 0us

# %%
feature_importance_series = pd.Series(catboost_model_2.feature_importances_, index=X_train_2_catboost.columns)
feature_importance_series
# Out:
# year                      0.0163
# month                     0.0226
# day_of_week               0.5558
# family                    0.7505
# store_city                0.0975
# store_state               0.1280
# store_type                0.1716
# store_cluster             0.1446
# holiday_locale            0.0371
# onpromotion               1.5142
# sin_7                     0.0565
# cos_7                     0.2299
# sin_30.5                  0.3152
# cos_30.5                  0.4305
# sin_365.25                0.1513
# cos_365.25                0.2616
# is_payday                 0.0112
# is_weekend                0.9045
# is_christmas              5.1991
# earthquake_effect         0.0435
# sales_lag_1               6.0298
# sales_lag_7              30.2018
# sales_lag_15              0.2528
# sales_lag_30              0.1520
# sales_lag_365             0.2573
# sales_rolling_mean_30     9.5336
# sales_rolling_std_30      0.1389
# sales_rolling_mean_15     8.0825
# sales_rolling_std_15      0.2291
# sales_rolling_median_7   14.0281
# sales_rolling_mean_7     17.1769
# is_holiday                0.0416
# is_event                  0.0025
# store_in_event_area       0.0652
# dcoilwtico                0.0795
# oil_lag_1                 0.0352
# oil_lag_7                 0.0824
# oil_lag_15                0.0723
# oil_lag_30                0.2583
# oil_lag_365               0.0676
# oil_rolling_mean_30       0.1489
# oil_rolling_std_30        0.0964
# oil_rolling_mean_15       0.0577
# oil_rolling_std_15        0.0889
# oil_rolling_median_7      0.0524
# oil_rolling_mean_7        0.0490
# transactions              1.6124
# is_discrete               0.0655
# dtype: float64

# %%
print('Top 10 important features')
feature_importance_series.nlargest(10)
# Out:
# Top 10 important features
# sales_lag_7              30.2018
# sales_rolling_mean_7     17.1769
# sales_rolling_median_7   14.0281
# sales_rolling_mean_30     9.5336
# sales_rolling_mean_15     8.0825
# sales_lag_1               6.0298
# is_christmas              5.1991
# transactions              1.6124
# onpromotion               1.5142
# is_weekend                0.9045
# dtype: float64

# %%
print('Top 10 non-important features')
feature_importance_series.nsmallest(10)
# Out:
# Top 10 non-important features
# is_event               0.0025
# is_payday              0.0112
# year                   0.0163
# month                  0.0226
# oil_lag_1              0.0352
# holiday_locale         0.0371
# is_holiday             0.0416
# earthquake_effect      0.0435
# oil_rolling_mean_7     0.0490
# oil_rolling_median_7   0.0524
# dtype: float64

# %%
# For each pair (store_nbr, family), we store a queue of sales (maximum of the last 30)
history = defaultdict(lambda: deque(maxlen=30))

# Filling in the history with the initial data
for _, row in prevalid_2.iterrows():
    key = (row.store_nbr, row.family)
    history[key].append(row.sales)

common_loss = 0

for d in range(DAYS_TO_PREDICT):
    prediction_date = start_valid_date + pd.Timedelta(days=d)
    valid_today = valid_2[valid_2['date'] == prediction_date].copy()

    # we create features incrementally
    sales_lag_1 = []
    sales_lag_7 = []
    rolling_mean_30 = []
    rolling_std_30 = []
    rolling_mean_15 = []
    rolling_std_15 = []
    rolling_median_7 = []
    rolling_mean_7 = []

    for _, row in valid_today.iterrows():
        key = (row.store_nbr, row.family)
        hist = history[key]

        # Lags
        sales_lag_1.append(hist[-1] if len(hist) >= 1 else np.nan)
        sales_lag_7.append(hist[-7] if len(hist) >= 7 else np.nan)

        # Rolling
        arr = np.array(hist)
        rolling_mean_30.append(arr[-30:].mean() if len(arr) > 0 else np.nan)
        rolling_std_30.append(arr[-30:].std() if len(arr) > 0 else np.nan)
        rolling_mean_15.append(arr[-15:].mean() if len(arr) > 0 else np.nan)
        rolling_std_15.append(arr[-15:].std() if len(arr) > 0 else np.nan)
        rolling_median_7.append(np.median(arr[-7:]) if len(arr) > 0 else np.nan)
        rolling_mean_7.append(arr[-7:].mean() if len(arr) > 0 else np.nan)

    valid_today['sales_lag_1'] = sales_lag_1
    valid_today['sales_lag_7'] = sales_lag_7
    valid_today['sales_rolling_mean_30'] = rolling_mean_30
    valid_today['sales_rolling_std_30'] = rolling_std_30
    valid_today['sales_rolling_mean_15'] = rolling_mean_15
    valid_today['sales_rolling_std_15'] = rolling_std_15
    valid_today['sales_rolling_median_7'] = rolling_median_7
    valid_today['sales_rolling_mean_7'] = rolling_mean_7

    # inference
    x_valid = valid_today[cat_features + num_features + ['is_discrete']]
    y_valid = np.array(valid_today['sales'])

    y_pred_log = catboost_model_2.predict(x_valid)
    y_pred = np.maximum(0, np.expm1(y_pred_log))

    mask_discrete = x_valid['is_discrete'] == 1
    y_pred[mask_discrete] = np.round(y_pred[mask_discrete])

    # refresh history
    for (_, row), pred in zip(valid_today.iterrows(), y_pred):
        key = (row.store_nbr, row.family)
        history[key].append(pred)

    #loss
    loss = root_mean_squared_log_error(y_valid, y_pred)
    print(f'Loss on {prediction_date}: {loss}')
    common_loss += loss

common_loss /= DAYS_TO_PREDICT
print(f'Common loss: {common_loss}')
# Out:
# Loss on 2017-08-01 00:00:00: 0.38371374442691897
# Loss on 2017-08-02 00:00:00: 0.3881194689419974
# Loss on 2017-08-03 00:00:00: 0.40061492633997414
# Loss on 2017-08-04 00:00:00: 0.4229008817482046
# Loss on 2017-08-05 00:00:00: 0.38933076459255345
# Loss on 2017-08-06 00:00:00: 0.40518150296637123
# Loss on 2017-08-07 00:00:00: 0.4040317920509503
# Loss on 2017-08-08 00:00:00: 0.4287231238086362
# Loss on 2017-08-09 00:00:00: 0.3994003428436572
# Loss on 2017-08-10 00:00:00: 0.41064304350961484
# Loss on 2017-08-11 00:00:00: 0.42855779353125373
# Loss on 2017-08-12 00:00:00: 0.4233175130353235
# Loss on 2017-08-13 00:00:00: 0.4262771391642664
# Loss on 2017-08-14 00:00:00: 0.43988749694987245
# Loss on 2017-08-15 00:00:00: 0.4273611646392805
# Common loss: 0.4118707132365917

# %% [markdown]
# Yes, there is enough stable data for the last year, the model is even better in the validation sample. But still, of course, the target is very scattered, let's try to divide it into 2 datasets.

# %%
del train_2
del valid_2
del history
del prevalid_2
del X_train_2_catboost
del y_train_2_catboost

# %% [markdown]
# # Approach 3 - divide the data by the type of target

# %% [markdown]
# I thought it would be better to separate the approaches with a function so that the memory is automatically cleared.

# %%
def approach_3_catboost():
  _train = train.copy()
  _valid = valid.copy()
  prevalid = data[
    (data['date'] >= (end_of_train - pd.Timedelta(days=30))) &
    (data['date'] <= end_of_train)
    ].copy()

  # discrete_train = _train[(_train['family'].isin(discrete_sales_families))]
  discrete_train = _train[(_train['family'].isin(discrete_sales_families)) & (_train['date'] >= '2016-01-01')]
  continuous_train = _train[_train['family'].isin(continuous_sales_families)]

  print('discrete_train', discrete_train.shape)
  print('continuous train', continuous_train.shape)
  print('valid', _valid.shape)

  continuous_X_train = continuous_train[cat_features + num_features]
  discrete_X_train = discrete_train[cat_features + num_features]

  discrete_y_train = np.log1p(discrete_train['sales'])
  continuous_y_train = np.log1p(continuous_train['sales'])

  discrete_train_pool = Pool(discrete_X_train, discrete_y_train, cat_features=cat_features)
  continuous_train_pool = Pool(continuous_X_train, continuous_y_train, cat_features=cat_features)



  discrete_model = CatBoostRegressor(loss_function='RMSE', random_seed=42, verbose=100, iterations=1000, task_type='GPU')
  continuous_model = CatBoostRegressor(loss_function='RMSE', random_seed=42, verbose=100, iterations=1000, task_type='GPU')



  print('\ndiscrete model\n')
  discrete_model.fit(discrete_train_pool)

  feature_importance_series = pd.Series(discrete_model.feature_importances_, index=discrete_X_train.columns)
  print('\ndiscrete model feature importances:')
  print(feature_importance_series)
  print('\nTop 10 important features')
  print(feature_importance_series.nlargest(10))
  print('\nTop 10 non-important features')
  print(feature_importance_series.nsmallest(10))




  print('\ncontinuous model\n')
  continuous_model.fit(continuous_train_pool)

  feature_importance_series = pd.Series(continuous_model.feature_importances_, index=continuous_X_train.columns)
  print('\ncontinuous model feature importances:')
  print(feature_importance_series)
  print('\nTop 10 important features')
  print(feature_importance_series.nlargest(10))
  print('\nTop 10 non-important features')
  print(feature_importance_series.nsmallest(10))



  # VALIDATION
  history = defaultdict(lambda: deque(maxlen=30))

  # Filling in the history with the initial data
  for _, row in prevalid.iterrows():
      key = (row.store_nbr, row.family)
      history[key].append(row.sales)


  common_loss = 0
  discrete_common_loss = 0
  continuous_common_loss = 0

  for d in range(DAYS_TO_PREDICT):
      prediction_date = start_valid_date + pd.Timedelta(days=d)
      valid_today = _valid[_valid['date'] == prediction_date].copy()

      # we create features incrementally
      sales_lag_1 = []
      sales_lag_7 = []
      rolling_mean_30 = []
      rolling_std_30 = []
      rolling_mean_15 = []
      rolling_std_15 = []
      rolling_median_7 = []
      rolling_mean_7 = []

      for _, row in valid_today.iterrows():
          key = (row.store_nbr, row.family)
          hist = history[key]

          # Lags
          sales_lag_1.append(hist[-1] if len(hist) >= 1 else np.nan)
          sales_lag_7.append(hist[-7] if len(hist) >= 7 else np.nan)

          # Rolling
          arr = np.array(hist)
          rolling_mean_30.append(arr[-30:].mean() if len(arr) > 0 else np.nan)
          rolling_std_30.append(arr[-30:].std() if len(arr) > 0 else np.nan)
          rolling_mean_15.append(arr[-15:].mean() if len(arr) > 0 else np.nan)
          rolling_std_15.append(arr[-15:].std() if len(arr) > 0 else np.nan)
          rolling_median_7.append(np.median(arr[-7:]) if len(arr) > 0 else np.nan)
          rolling_mean_7.append(arr[-7:].mean() if len(arr) > 0 else np.nan)

      valid_today['sales_lag_1'] = sales_lag_1
      valid_today['sales_lag_7'] = sales_lag_7
      valid_today['sales_rolling_mean_30'] = rolling_mean_30
      valid_today['sales_rolling_std_30'] = rolling_std_30
      valid_today['sales_rolling_mean_15'] = rolling_mean_15
      valid_today['sales_rolling_std_15'] = rolling_std_15
      valid_today['sales_rolling_median_7'] = rolling_median_7
      valid_today['sales_rolling_mean_7'] = rolling_mean_7

      # inference

      x_valid = valid_today[cat_features + num_features]
      y_valid = np.array(valid_today['sales'])

      discrete_x_valid = x_valid[(valid_today['family'].isin(discrete_sales_families))]
      continuous_x_valid = x_valid[(valid_today['family'].isin(continuous_sales_families))]
      discrete_y_valid = y_valid[(valid_today['family'].isin(discrete_sales_families))]
      continuous_y_valid = y_valid[(valid_today['family'].isin(continuous_sales_families))]

      discrete_y_pred = np.round(np.maximum(0, np.expm1(discrete_model.predict(discrete_x_valid)) ))
      continuous_y_pred = np.maximum(0, np.expm1(continuous_model.predict(continuous_x_valid)))

      y_pred = pd.concat([
        pd.Series(discrete_y_pred, index=discrete_x_valid.index),
        pd.Series(continuous_y_pred, index=continuous_x_valid.index)
      ]).sort_index()


      # refresh history
      for (_, row), pred in zip(valid_today.iterrows(), y_pred):
          key = (row.store_nbr, row.family)
          history[key].append(pred)

      #loss
      discrete_loss = root_mean_squared_log_error(discrete_y_valid, discrete_y_pred)
      continuous_loss = root_mean_squared_log_error(continuous_y_valid, continuous_y_pred)
      loss = root_mean_squared_log_error(y_valid, y_pred)
      print('\n')
      print(f'Discrete model loss on {prediction_date}: {discrete_loss}')
      print(f'Continuous model loss on {prediction_date}: {continuous_loss}')
      print(f'Loss on {prediction_date}: {loss}')

      discrete_common_loss += discrete_loss
      continuous_common_loss += continuous_loss
      common_loss += loss

  common_loss /= DAYS_TO_PREDICT
  discrete_common_loss /= DAYS_TO_PREDICT
  continuous_common_loss /= DAYS_TO_PREDICT
  print('\n\n')
  print(f'Common loss: {common_loss}')
  print(f'Common dicsrete loss: {discrete_common_loss}')
  print(f'Common continuous loss: {continuous_common_loss}')
  print('\n')

# %%
approach_3_catboost()
# Out:
# discrete_train (767232, 51)
# continuous train (827172, 51)
# valid (26730, 51)
#
# discrete model
#
# Learning rate set to 0.096436
# 0:	learn: 2.1972965	total: 114ms	remaining: 1m 53s
# 100:	learn: 0.4525482	total: 8.17s	remaining: 1m 12s
# 200:	learn: 0.4387510	total: 17.2s	remaining: 1m 8s
# 300:	learn: 0.4323281	total: 26.5s	remaining: 1m 1s
# 400:	learn: 0.4279581	total: 34.4s	remaining: 51.4s
# 500:	learn: 0.4250109	total: 43.8s	remaining: 43.6s
# 600:	learn: 0.4228835	total: 53.1s	remaining: 35.2s
# 700:	learn: 0.4210749	total: 1m 1s	remaining: 26s
# 800:	learn: 0.4195992	total: 1m 10s	remaining: 17.5s
# 900:	learn: 0.4181016	total: 1m 19s	remaining: 8.75s
# 999:	learn: 0.4169936	total: 1m 27s	remaining: 0us
#
# discrete model feature importances:
# year                      0.0190
# month                     0.0250
# day_of_week               0.6913
# family                    1.1490
# store_city                0.1166
# store_state               0.1481
# store_type                0.2264
# store_cluster             0.1249
# holiday_locale            0.0341
# onpromotion               2.2286
# sin_7                     0.0988
# cos_7                     0.3965
# sin_30.5                  0.3378
# cos_30.5                  0.3803
# sin_365.25                0.2009
# cos_365.25                0.2166
# is_payday                 0.0148
# is_weekend                1.2197
# is_christmas              4.1944
# earthquake_effect         0.0505
# sales_lag_1               6.5444
# sales_lag_7              23.5600
# sales_lag_15              0.2019
# sales_lag_30              0.1802
# sales_lag_365             0.4216
# sales_rolling_mean_30    13.1273
# sales_rolling_std_30      0.9341
# sales_rolling_mean_15     6.6127
# sales_rolling_std_15      0.3210
# sales_rolling_median_7   16.7004
# sales_rolling_mean_7     16.1143
# is_holiday                0.0631
# is_event                  0.0045
# store_in_event_area       0.1044
# dcoilwtico                0.1354
# oil_lag_1                 0.0339
# oil_lag_7                 0.1397
# oil_lag_15                0.3180
# oil_lag_30                0.1567
# oil_lag_365               0.1416
# oil_rolling_mean_30       0.0826
# oil_rolling_std_30        0.0902
# oil_rolling_mean_15       0.1702
# oil_rolling_std_15        0.1047
# oil_rolling_median_7      0.0569
# oil_rolling_mean_7        0.0864
# transactions              1.7209
# dtype: float64
#
# Top 10 important features
# sales_lag_7              23.5600
# sales_rolling_median_7   16.7004
# sales_rolling_mean_7     16.1143
# sales_rolling_mean_30    13.1273
# sales_rolling_mean_15     6.6127
# sales_lag_1               6.5444
# is_christmas              4.1944
# onpromotion               2.2286
# transactions              1.7209
# is_weekend                1.2197
# dtype: float64
#
# Top 10 non-important features
# is_event               0.0045
# is_payday              0.0148
# year                   0.0190
# month                  0.0250
# oil_lag_1              0.0339
# holiday_locale         0.0341
# earthquake_effect      0.0505
# oil_rolling_median_7   0.0569
# is_holiday             0.0631
# oil_rolling_mean_30    0.0826
# dtype: float64
#
# continuous model
#
# Learning rate set to 0.097391
# 0:	learn: 2.1938395	total: 116ms	remaining: 1m 55s
# 100:	learn: 0.3350181	total: 11.2s	remaining: 1m 40s
# 200:	learn: 0.3084162	total: 21.2s	remaining: 1m 24s
# 300:	learn: 0.2975047	total: 31.5s	remaining: 1m 13s
# 400:	learn: 0.2901959	total: 41.7s	remaining: 1m 2s
# 500:	learn: 0.2844618	total: 52.3s	remaining: 52.1s
# 600:	learn: 0.2804203	total: 1m 2s	remaining: 41.7s
# 700:	learn: 0.2764447	total: 1m 12s	remaining: 30.9s
# 800:	learn: 0.2734698	total: 1m 23s	remaining: 20.7s
# 900:	learn: 0.2711570	total: 1m 34s	remaining: 10.3s
# 999:	learn: 0.2693225	total: 1m 44s	remaining: 0us
#
# continuous model feature importances:
# year                      0.1257
# month                     0.1933
# day_of_week               0.4772
# family                    1.0684
# store_city                0.0815
# store_state               0.0928
# store_type                0.2145
# store_cluster             0.1374
# holiday_locale            0.0648
# onpromotion               0.8621
# sin_7                     0.0723
# cos_7                     0.0639
# sin_30.5                  0.4848
# cos_30.5                  0.5641
# sin_365.25                0.1433
# cos_365.25                1.5097
# is_payday                 0.0074
# is_weekend                0.4660
# is_christmas              5.3375
# earthquake_effect         0.0139
# sales_lag_1              15.3283
# sales_lag_7              20.7631
# sales_lag_15              0.0676
# sales_lag_30              0.0708
# sales_lag_365             0.2223
# sales_rolling_mean_30     3.4664
# sales_rolling_std_30      0.3236
# sales_rolling_mean_15     0.5660
# sales_rolling_std_15      0.1736
# sales_rolling_median_7   17.8181
# sales_rolling_mean_7     20.9027
# is_holiday                0.0276
# is_event                  0.0313
# store_in_event_area       0.0940
# dcoilwtico                0.0500
# oil_lag_1                 0.1049
# oil_lag_7                 0.0586
# oil_lag_15                0.0634
# oil_lag_30                0.0484
# oil_lag_365               0.2946
# oil_rolling_mean_30       0.0426
# oil_rolling_std_30        0.2051
# oil_rolling_mean_15       0.0415
# oil_rolling_std_15        0.2132
# oil_rolling_median_7      0.0885
# oil_rolling_mean_7        0.0625
# transactions              6.8908
# dtype: float64
#
# Top 10 important features
# sales_rolling_mean_7     20.9027
# sales_lag_7              20.7631
# sales_rolling_median_7   17.8181
# sales_lag_1              15.3283
# transactions              6.8908
# is_christmas              5.3375
# sales_rolling_mean_30     3.4664
# cos_365.25                1.5097
# family                    1.0684
# onpromotion               0.8621
# dtype: float64
#
# Top 10 non-important features
# is_payday             0.0074
# earthquake_effect     0.0139
# is_holiday            0.0276
# is_event              0.0313
# oil_rolling_mean_15   0.0415
# oil_rolling_mean_30   0.0426
# oil_lag_30            0.0484
# dcoilwtico            0.0500
# oil_lag_7             0.0586
# oil_rolling_mean_7    0.0625
# dtype: float64
#
#
# Discrete model loss on 2017-08-01 00:00:00: 0.4264203345403747
# Continuous model loss on 2017-08-01 00:00:00: 0.23757105651974353
# Loss on 2017-08-01 00:00:00: 0.38423411830477455
#
#
# Discrete model loss on 2017-08-02 00:00:00: 0.4238624826475667
# Continuous model loss on 2017-08-02 00:00:00: 0.24075105567014538
# Loss on 2017-08-02 00:00:00: 0.3827126201672546
#
#
# Discrete model loss on 2017-08-03 00:00:00: 0.43060417225946024
# Continuous model loss on 2017-08-03 00:00:00: 0.26044416634778533
# Loss on 2017-08-03 00:00:00: 0.3915996467511428
#
#
# Discrete model loss on 2017-08-04 00:00:00: 0.4630573114602156
# Continuous model loss on 2017-08-04 00:00:00: 0.26642061104854786
# Loss on 2017-08-04 00:00:00: 0.4186902104451398
#
#
# Discrete model loss on 2017-08-05 00:00:00: 0.4168651179921674
# Continuous model loss on 2017-08-05 00:00:00: 0.26073620474867726
# Loss on 2017-08-05 00:00:00: 0.38068864851491313
#
#
# Discrete model loss on 2017-08-06 00:00:00: 0.4415254449796917
# Continuous model loss on 2017-08-06 00:00:00: 0.2484232743650347
# Loss on 2017-08-06 00:00:00: 0.39825758204902034
#
#
# Discrete model loss on 2017-08-07 00:00:00: 0.44686553946949475
# Continuous model loss on 2017-08-07 00:00:00: 0.24105637378373362
# Loss on 2017-08-07 00:00:00: 0.40134263404774345
#
#
# Discrete model loss on 2017-08-08 00:00:00: 0.45998310644428564
# Continuous model loss on 2017-08-08 00:00:00: 0.296834476123983
# Loss on 2017-08-08 00:00:00: 0.4217935497114973
#
#
# Discrete model loss on 2017-08-09 00:00:00: 0.4390050848578149
# Continuous model loss on 2017-08-09 00:00:00: 0.22794553603034914
# Loss on 2017-08-09 00:00:00: 0.39285449751977086
#
#
# Discrete model loss on 2017-08-10 00:00:00: 0.45477646809164324
# Continuous model loss on 2017-08-10 00:00:00: 0.26737650277811237
# Loss on 2017-08-10 00:00:00: 0.4122051199621193
#
#
# Discrete model loss on 2017-08-11 00:00:00: 0.45955563292082713
# Continuous model loss on 2017-08-11 00:00:00: 0.2754957348904652
# Loss on 2017-08-11 00:00:00: 0.41748432064434887
#
#
# Discrete model loss on 2017-08-12 00:00:00: 0.46258698696580053
# Continuous model loss on 2017-08-12 00:00:00: 0.2927366287711592
# Loss on 2017-08-12 00:00:00: 0.42308154872142256
#
#
# Discrete model loss on 2017-08-13 00:00:00: 0.46322212756797354
# Continuous model loss on 2017-08-13 00:00:00: 0.27838909882590857
# Loss on 2017-08-13 00:00:00: 0.42094043918826507
#
#
# Discrete model loss on 2017-08-14 00:00:00: 0.48895559694093865
# Continuous model loss on 2017-08-14 00:00:00: 0.25934941147954
# Loss on 2017-08-14 00:00:00: 0.4384276614887371
#
#
# Discrete model loss on 2017-08-15 00:00:00: 0.4531287528033845
# Continuous model loss on 2017-08-15 00:00:00: 0.2854336518428055
# Loss on 2017-08-15 00:00:00: 0.414182924206878
#
#
#
# Common loss: 0.4065663681148686
# Common dicsrete loss: 0.4486942773294426
# Common continuous loss: 0.2625975855483994

# %% [markdown]
# # Approach 4 - try 33 models

# %%
valid.isnull().sum()
# Out:
# date                          0
# store_nbr                     0
# family                        0
# id                            0
# sales                         0
# onpromotion                   0
# year                          0
# month                         0
# day_of_week                   0
# sin_7                         0
# cos_7                         0
# sin_30.5                      0
# cos_30.5                      0
# sin_365.25                    0
# cos_365.25                    0
# is_payday                     0
# is_weekend                    0
# is_christmas                  0
# earthquake_effect             0
# sales_lag_1               26730
# sales_lag_7               16038
# sales_lag_15                  0
# sales_lag_30                  0
# sales_lag_365                 0
# sales_rolling_mean_30         0
# sales_rolling_std_30          0
# sales_rolling_mean_15         0
# sales_rolling_std_15          0
# sales_rolling_median_7    16038
# sales_rolling_mean_7      16038
# store_city                    0
# store_state                   0
# store_type                    0
# store_cluster                 0
# holiday_locale                0
# is_holiday                    0
# is_event                      0
# store_in_event_area           0
# dcoilwtico                    0
# oil_lag_1                     0
# oil_lag_7                     0
# oil_lag_15                    0
# oil_lag_30                    0
# oil_lag_365                   0
# oil_rolling_mean_30           0
# oil_rolling_std_30            0
# oil_rolling_mean_15           0
# oil_rolling_std_15            0
# oil_rolling_median_7          0
# oil_rolling_mean_7            0
# transactions                  0
# dtype: int64

# %%
def approach_4_catboost():
    _train = train.copy()
    _valid = valid.copy()

    prevalid = data[
        (data['date'] >= (end_of_train - pd.Timedelta(days=30))) &
        (data['date'] <= end_of_train)
    ].copy()

    families = _train['family'].unique()
    models = {}  # family -> CatBoost model

    _cat_features = cat_features.copy()
    _cat_features.remove('family')

    for fam in families:
        fam_train = _train[_train['family'] == fam]
        X_train = fam_train[_cat_features + num_features]
        y_train = np.log1p(fam_train['sales'])

        train_pool = Pool(X_train, y_train, cat_features=_cat_features)

        print(f"\nTraining model for family: {fam}\n")
        print('Data size:', train_pool.shape, '\n')
        model = CatBoostRegressor(
            loss_function='RMSE',
            random_seed=42,
            verbose=500,
            iterations=1000,
            task_type='GPU'
        )
        model.fit(train_pool)
        models[fam] = model

    history = defaultdict(lambda: deque(maxlen=30))
    for _, row in prevalid.iterrows():
        key = (row.store_nbr, row.family)
        history[key].append(row.sales)

    common_loss = 0
    for d in range(DAYS_TO_PREDICT):
        prediction_date = start_valid_date + pd.Timedelta(days=d)
        valid_today = _valid[_valid['date'] == prediction_date].copy()

        sales_lag_1, sales_lag_7 = [], []
        rolling_mean_30, rolling_std_30 = [], []
        rolling_mean_15, rolling_std_15 = [], []
        rolling_median_7, rolling_mean_7 = [], []

        for _, row in valid_today.iterrows():
            key = (row.store_nbr, row.family)
            hist = history[key]

            sales_lag_1.append(hist[-1] if len(hist) >= 1 else np.nan)
            sales_lag_7.append(hist[-7] if len(hist) >= 7 else np.nan)

            arr = np.array(hist)
            rolling_mean_30.append(arr[-30:].mean() if len(arr) > 0 else np.nan)
            rolling_std_30.append(arr[-30:].std() if len(arr) > 0 else np.nan)
            rolling_mean_15.append(arr[-15:].mean() if len(arr) > 0 else np.nan)
            rolling_std_15.append(arr[-15:].std() if len(arr) > 0 else np.nan)
            rolling_median_7.append(np.median(arr[-7:]) if len(arr) > 0 else np.nan)
            rolling_mean_7.append(arr[-7:].mean() if len(arr) > 0 else np.nan)

        valid_today['sales_lag_1'] = sales_lag_1
        valid_today['sales_lag_7'] = sales_lag_7
        valid_today['sales_rolling_mean_30'] = rolling_mean_30
        valid_today['sales_rolling_std_30'] = rolling_std_30
        valid_today['sales_rolling_mean_15'] = rolling_mean_15
        valid_today['sales_rolling_std_15'] = rolling_std_15
        valid_today['sales_rolling_median_7'] = rolling_median_7
        valid_today['sales_rolling_mean_7'] = rolling_mean_7

        y_valid = np.array(valid_today['sales'])
        y_pred = []

        for idx, row in valid_today.iterrows():
            fam = row['family']
            model = models[fam]
            x_row = row[_cat_features + num_features].to_frame().T
            pred = np.expm1(model.predict(x_row))[0]

            if fam in discrete_sales_families:
              pred = round(pred)

            pred = max(0, pred)
            y_pred.append(pred)

            key = (row.store_nbr, row.family)
            history[key].append(pred)

        y_pred = np.array(y_pred)
        loss = root_mean_squared_log_error(y_valid, y_pred)
        print(f"Loss on {prediction_date}: {loss}")
        common_loss += loss

    common_loss /= DAYS_TO_PREDICT
    print(f"Common loss: {common_loss}")

    return models

# %%
catboost_models_4  = approach_4_catboost()
# Out:
# Training model for family: AUTOMOTIVE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.8468333	total: 25.1ms	remaining: 25s
# 500:	learn: 0.4981984	total: 11.1s	remaining: 11.1s
# 999:	learn: 0.4861685	total: 21.4s	remaining: 0us
#
# Training model for family: BABY CARE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.2395136	total: 17.1ms	remaining: 17.1s
# 500:	learn: 0.1728735	total: 8.42s	remaining: 8.38s
# 999:	learn: 0.1599786	total: 19.4s	remaining: 0us
#
# Training model for family: BEAUTY
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.8520507	total: 17ms	remaining: 17s
# 500:	learn: 0.4403171	total: 10.9s	remaining: 10.8s
# 999:	learn: 0.4295221	total: 21.4s	remaining: 0us
#
# Training model for family: BEVERAGES
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 2.0662860	total: 17.5ms	remaining: 17.5s
# 500:	learn: 0.1590787	total: 10.5s	remaining: 10.4s
# 999:	learn: 0.1448950	total: 19s	remaining: 0us
#
# Training model for family: BOOKS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.1925217	total: 83.2ms	remaining: 1m 23s
# 500:	learn: 0.0934566	total: 10.1s	remaining: 10.1s
# 999:	learn: 0.0796836	total: 20.5s	remaining: 0us
#
# Training model for family: BREAD/BAKERY
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.6703759	total: 30.8ms	remaining: 30.8s
# 500:	learn: 0.1427884	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.1320461	total: 21.6s	remaining: 0us
#
# Training model for family: CELEBRATION
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.2705737	total: 19.7ms	remaining: 19.7s
# 500:	learn: 0.3987286	total: 9.96s	remaining: 9.91s
# 999:	learn: 0.3848719	total: 19.4s	remaining: 0us
#
# Training model for family: CLEANING
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.8397049	total: 16.9ms	remaining: 16.9s
# 500:	learn: 0.1421853	total: 10.8s	remaining: 10.7s
# 999:	learn: 0.1275190	total: 21.8s	remaining: 0us
#
# Training model for family: DAIRY
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.7920409	total: 17.1ms	remaining: 17s
# 500:	learn: 0.1299461	total: 10.7s	remaining: 10.7s
# 999:	learn: 0.1162043	total: 21.2s	remaining: 0us
#
# Training model for family: DELI
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.5122341	total: 18.5ms	remaining: 18.5s
# 500:	learn: 0.1510978	total: 8.56s	remaining: 8.53s
# 999:	learn: 0.1404151	total: 19.6s	remaining: 0us
#
# Training model for family: EGGS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.4581994	total: 17.1ms	remaining: 17.1s
# 500:	learn: 0.2663971	total: 11.1s	remaining: 11.1s
# 999:	learn: 0.2530143	total: 22s	remaining: 0us
#
# Training model for family: FROZEN FOODS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.5070304	total: 17.6ms	remaining: 17.6s
# 500:	learn: 0.2922506	total: 10.8s	remaining: 10.8s
# 999:	learn: 0.2770549	total: 21.8s	remaining: 0us
#
# Training model for family: GROCERY I
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 2.1521971	total: 18.4ms	remaining: 18.4s
# 500:	learn: 0.1303593	total: 9.33s	remaining: 9.29s
# 999:	learn: 0.1166989	total: 19.3s	remaining: 0us
#
# Training model for family: GROCERY II
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.2561752	total: 16.9ms	remaining: 16.8s
# 500:	learn: 0.4922809	total: 10.8s	remaining: 10.8s
# 999:	learn: 0.4760544	total: 21.7s	remaining: 0us
#
# Training model for family: HARDWARE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.5965920	total: 20.1ms	remaining: 20.1s
# 500:	learn: 0.4911314	total: 10.5s	remaining: 10.4s
# 999:	learn: 0.4791825	total: 20.8s	remaining: 0us
#
# Training model for family: HOME AND KITCHEN I
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.5323333	total: 17.2ms	remaining: 17.2s
# 500:	learn: 0.4594808	total: 8.57s	remaining: 8.53s
# 999:	learn: 0.4434064	total: 19.3s	remaining: 0us
#
# Training model for family: HOME AND KITCHEN II
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.4393173	total: 33.4ms	remaining: 33.4s
# 500:	learn: 0.3614289	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.3478945	total: 21.7s	remaining: 0us
#
# Training model for family: HOME APPLIANCES
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.4382470	total: 17.2ms	remaining: 17.2s
# 500:	learn: 0.3351589	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.3244990	total: 19.4s	remaining: 0us
#
# Training model for family: HOME CARE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 2.5656033	total: 104ms	remaining: 1m 44s
# 500:	learn: 0.1423640	total: 9.71s	remaining: 9.67s
# 999:	learn: 0.1217202	total: 20.7s	remaining: 0us
#
# Training model for family: LADIESWEAR
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.2924122	total: 17.6ms	remaining: 17.6s
# 500:	learn: 0.3291335	total: 10.6s	remaining: 10.5s
# 999:	learn: 0.3128505	total: 21.2s	remaining: 0us
#
# Training model for family: LAWN AND GARDEN
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.1581112	total: 17ms	remaining: 17s
# 500:	learn: 0.4602682	total: 10.4s	remaining: 10.3s
# 999:	learn: 0.4428691	total: 19.3s	remaining: 0us
#
# Training model for family: LINGERIE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.9587349	total: 16.9ms	remaining: 16.9s
# 500:	learn: 0.5751882	total: 10.7s	remaining: 10.6s
# 999:	learn: 0.5609561	total: 22.1s	remaining: 0us
#
# Training model for family: LIQUOR,WINE,BEER
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.7607573	total: 17.5ms	remaining: 17.5s
# 500:	learn: 0.4706273	total: 11s	remaining: 10.9s
# 999:	learn: 0.4425850	total: 21.8s	remaining: 0us
#
# Training model for family: MAGAZINES
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.9383292	total: 17.2ms	remaining: 17.1s
# 500:	learn: 0.3610564	total: 9.22s	remaining: 9.19s
# 999:	learn: 0.3469609	total: 19.5s	remaining: 0us
#
# Training model for family: MEATS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.6231774	total: 30.9ms	remaining: 30.9s
# 500:	learn: 0.1993199	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.1849976	total: 21.8s	remaining: 0us
#
# Training model for family: PERSONAL CARE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.5182490	total: 17.3ms	remaining: 17.3s
# 500:	learn: 0.1800837	total: 10.9s	remaining: 10.8s
# 999:	learn: 0.1663092	total: 21.8s	remaining: 0us
#
# Training model for family: PET SUPPLIES
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.0365152	total: 16.7ms	remaining: 16.7s
# 500:	learn: 0.3382668	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.3257392	total: 19.5s	remaining: 0us
#
# Training model for family: PLAYERS AND ELECTRONICS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.1568901	total: 17.5ms	remaining: 17.5s
# 500:	learn: 0.3569110	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.3442606	total: 22.3s	remaining: 0us
#
# Training model for family: POULTRY
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.6498515	total: 17.1ms	remaining: 17s
# 500:	learn: 0.2123319	total: 10.9s	remaining: 10.8s
# 999:	learn: 0.1977577	total: 21.9s	remaining: 0us
#
# Training model for family: PREPARED FOODS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.3758062	total: 17.2ms	remaining: 17.2s
# 500:	learn: 0.2588735	total: 10.9s	remaining: 10.8s
# 999:	learn: 0.2472180	total: 19.5s	remaining: 0us
#
# Training model for family: PRODUCE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 3.1913008	total: 85.9ms	remaining: 1m 25s
# 500:	learn: 0.2830188	total: 10.7s	remaining: 10.6s
# 999:	learn: 0.2551273	total: 21.9s	remaining: 0us
#
# Training model for family: SCHOOL AND OFFICE SUPPLIES
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.8089248	total: 17.6ms	remaining: 17.6s
# 500:	learn: 0.3196199	total: 11s	remaining: 11s
# 999:	learn: 0.3046615	total: 21.3s	remaining: 0us
#
# Training model for family: SEAFOOD
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.4198287	total: 16.8ms	remaining: 16.8s
# 500:	learn: 0.4376160	total: 10.6s	remaining: 10.5s
# 999:	learn: 0.4213072	total: 19.1s	remaining: 0us
# Loss on 2017-08-01 00:00:00: 0.3756711492789038
# Loss on 2017-08-02 00:00:00: 0.3773661111791427
# Loss on 2017-08-03 00:00:00: 0.37090289304742274
# Loss on 2017-08-04 00:00:00: 0.40304722319274033
# Loss on 2017-08-05 00:00:00: 0.36172300282852204
# Loss on 2017-08-06 00:00:00: 0.38530478772448806
# Loss on 2017-08-07 00:00:00: 0.38458949569059125
# Loss on 2017-08-08 00:00:00: 0.41570236485660605
# Loss on 2017-08-09 00:00:00: 0.3821677951989071
# Loss on 2017-08-10 00:00:00: 0.3882929891163555
# Loss on 2017-08-11 00:00:00: 0.41175774621749966
# Loss on 2017-08-12 00:00:00: 0.4047247834380101
# Loss on 2017-08-13 00:00:00: 0.39919532236321104
# Loss on 2017-08-14 00:00:00: 0.41868248436112737
# Loss on 2017-08-15 00:00:00: 0.4156059798616088
# Common loss: 0.39298227522367585

# %% [markdown]
# # Approach 5 - try 33 models - individual for each family (info taken step 2 - Analysis)

# %%
def approach_4_catboost():
    _train = train.copy()
    _valid = valid.copy()

    prevalid = data[
        (data['date'] >= (end_of_train - pd.Timedelta(days=30))) &
        (data['date'] <= end_of_train)
    ].copy()

    families = _train['family'].unique()
    models = {}  # family -> CatBoost model

    _cat_features = cat_features.copy()
    _cat_features.remove('family')

    for fam in families:
        fam_train = _train[_train['family'] == fam]
        if fam in ['BABY CARE', 'MAGAZINES']:
          fam_train = fam_train[fam_train['date'] >= '2016-01-01']

        elif fam in ['BOOKS', 'LAWN AND GARDEN']:
          fam_train = fam_train[fam_train['date'] >= '2016-10-08']

        elif fam in ['CELEBRATION', 'HOME CARE', 'LADIESWEAR', 'PET SUPPLIES', 'PLAYERS AND ELECTRONICS', 'PRODUCE', 'SCHOOL AND OFFICE SUPPLIES']:
          fam_train = fam_train[fam_train['date'] >= '2015-06-01']

        elif fam in ['HOME AND KITCHEN I', 'HOME AND KITCHEN II']:
          fam_train = fam_train[fam_train['date'] >= '2015-01-01']


        X_train = fam_train[_cat_features + num_features]
        y_train = np.log1p(fam_train['sales'])

        train_pool = Pool(X_train, y_train, cat_features=_cat_features)

        print(f"\nTraining model for family: {fam}\n")
        print('Data size:', train_pool.shape, '\n')
        model = CatBoostRegressor(
            loss_function='RMSE',
            random_seed=42,
            verbose=500,
            iterations=1000,
            task_type='GPU'
        )
        model.fit(train_pool)
        models[fam] = model

    history = defaultdict(lambda: deque(maxlen=30))
    for _, row in prevalid.iterrows():
        key = (row.store_nbr, row.family)
        history[key].append(row.sales)

    common_loss = 0
    for d in range(DAYS_TO_PREDICT):
        prediction_date = start_valid_date + pd.Timedelta(days=d)
        valid_today = _valid[_valid['date'] == prediction_date].copy()

        sales_lag_1, sales_lag_7 = [], []
        rolling_mean_30, rolling_std_30 = [], []
        rolling_mean_15, rolling_std_15 = [], []
        rolling_median_7, rolling_mean_7 = [], []

        for _, row in valid_today.iterrows():
            key = (row.store_nbr, row.family)
            hist = history[key]

            sales_lag_1.append(hist[-1] if len(hist) >= 1 else np.nan)
            sales_lag_7.append(hist[-7] if len(hist) >= 7 else np.nan)

            arr = np.array(hist)
            rolling_mean_30.append(arr[-30:].mean() if len(arr) > 0 else np.nan)
            rolling_std_30.append(arr[-30:].std() if len(arr) > 0 else np.nan)
            rolling_mean_15.append(arr[-15:].mean() if len(arr) > 0 else np.nan)
            rolling_std_15.append(arr[-15:].std() if len(arr) > 0 else np.nan)
            rolling_median_7.append(np.median(arr[-7:]) if len(arr) > 0 else np.nan)
            rolling_mean_7.append(arr[-7:].mean() if len(arr) > 0 else np.nan)

        valid_today['sales_lag_1'] = sales_lag_1
        valid_today['sales_lag_7'] = sales_lag_7
        valid_today['sales_rolling_mean_30'] = rolling_mean_30
        valid_today['sales_rolling_std_30'] = rolling_std_30
        valid_today['sales_rolling_mean_15'] = rolling_mean_15
        valid_today['sales_rolling_std_15'] = rolling_std_15
        valid_today['sales_rolling_median_7'] = rolling_median_7
        valid_today['sales_rolling_mean_7'] = rolling_mean_7

        y_valid = np.array(valid_today['sales'])
        y_pred = []

        for idx, row in valid_today.iterrows():
            fam = row['family']
            model = models[fam]
            x_row = row[_cat_features + num_features].to_frame().T
            pred = np.expm1(model.predict(x_row))[0]

            if fam in discrete_sales_families:
              pred = round(pred)

            pred = max(0, pred)
            y_pred.append(pred)

            key = (row.store_nbr, row.family)
            history[key].append(pred)

        y_pred = np.array(y_pred)
        loss = root_mean_squared_log_error(y_valid, y_pred)
        print(f"Loss on {prediction_date}: {loss}")
        common_loss += loss

    common_loss /= DAYS_TO_PREDICT
    print(f"Common loss: {common_loss}")

    return models

# %%
catboost_models_4  = approach_4_catboost()
# Out:
# Training model for family: AUTOMOTIVE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.8468333	total: 24.5ms	remaining: 24.5s
# 500:	learn: 0.4981984	total: 10.2s	remaining: 10.2s
# 999:	learn: 0.4861685	total: 20s	remaining: 0us
#
# Training model for family: BABY CARE
#
# Data size: (31968, 46)
#
# Learning rate set to 0.063596
# 0:	learn: 0.3484869	total: 27.1ms	remaining: 27s
# 500:	learn: 0.2770358	total: 17.8s	remaining: 17.7s
# 999:	learn: 0.2701070	total: 33.7s	remaining: 0us
#
# Training model for family: BEAUTY
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.8520507	total: 16.9ms	remaining: 16.9s
# 500:	learn: 0.4403170	total: 10.5s	remaining: 10.5s
# 999:	learn: 0.4295234	total: 19.2s	remaining: 0us
#
# Training model for family: BEVERAGES
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 2.0662860	total: 88.2ms	remaining: 1m 28s
# 500:	learn: 0.1590787	total: 9.75s	remaining: 9.71s
# 999:	learn: 0.1448950	total: 20.7s	remaining: 0us
#
# Training model for family: BOOKS
#
# Data size: (16308, 46)
#
# Learning rate set to 0.058229
# 0:	learn: 0.4336614	total: 24.3ms	remaining: 24.3s
# 500:	learn: 0.2519772	total: 14.7s	remaining: 14.7s
# 999:	learn: 0.2419977	total: 29.4s	remaining: 0us
#
# Training model for family: BREAD/BAKERY
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.6703759	total: 88.3ms	remaining: 1m 28s
# 500:	learn: 0.1427884	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.1320519	total: 21.9s	remaining: 0us
#
# Training model for family: CELEBRATION
#
# Data size: (43740, 46)
#
# Learning rate set to 0.066262
# 0:	learn: 0.9293590	total: 28.7ms	remaining: 28.7s
# 500:	learn: 0.5154733	total: 15.9s	remaining: 15.9s
# 999:	learn: 0.5057184	total: 34.5s	remaining: 0us
#
# Training model for family: CLEANING
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.8397049	total: 17.4ms	remaining: 17.4s
# 500:	learn: 0.1421854	total: 10.5s	remaining: 10.5s
# 999:	learn: 0.1275190	total: 19.6s	remaining: 0us
#
# Training model for family: DAIRY
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.7920409	total: 17.1ms	remaining: 17.1s
# 500:	learn: 0.1299460	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.1162043	total: 21.9s	remaining: 0us
#
# Training model for family: DELI
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.5122341	total: 17.6ms	remaining: 17.6s
# 500:	learn: 0.1512285	total: 10.6s	remaining: 10.6s
# 999:	learn: 0.1403520	total: 21.3s	remaining: 0us
#
# Training model for family: EGGS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.4581994	total: 17.7ms	remaining: 17.7s
# 500:	learn: 0.2663971	total: 8.66s	remaining: 8.63s
# 999:	learn: 0.2530020	total: 19.6s	remaining: 0us
#
# Training model for family: FROZEN FOODS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.5070304	total: 17.3ms	remaining: 17.3s
# 500:	learn: 0.2922506	total: 10.8s	remaining: 10.8s
# 999:	learn: 0.2771103	total: 21.6s	remaining: 0us
#
# Training model for family: GROCERY I
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 2.1521971	total: 17.2ms	remaining: 17.2s
# 500:	learn: 0.1303593	total: 10.7s	remaining: 10.6s
# 999:	learn: 0.1166989	total: 20.3s	remaining: 0us
#
# Training model for family: GROCERY II
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.2561752	total: 25ms	remaining: 25s
# 500:	learn: 0.4922809	total: 8.65s	remaining: 8.62s
# 999:	learn: 0.4760544	total: 19.3s	remaining: 0us
#
# Training model for family: HARDWARE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.5965920	total: 17.5ms	remaining: 17.5s
# 500:	learn: 0.4910924	total: 10.3s	remaining: 10.3s
# 999:	learn: 0.4791072	total: 20.6s	remaining: 0us
#
# Training model for family: HOME AND KITCHEN I
#
# Data size: (51894, 46)
#
# Learning rate set to 0.067763
# 0:	learn: 0.9948018	total: 16.7ms	remaining: 16.6s
# 500:	learn: 0.5183306	total: 8.17s	remaining: 8.13s
# 999:	learn: 0.4977848	total: 19s	remaining: 0us
#
# Training model for family: HOME AND KITCHEN II
#
# Data size: (51894, 46)
#
# Learning rate set to 0.067763
# 0:	learn: 0.9847307	total: 18.2ms	remaining: 18.2s
# 500:	learn: 0.4214537	total: 10.5s	remaining: 10.5s
# 999:	learn: 0.4037508	total: 21.2s	remaining: 0us
#
# Training model for family: HOME APPLIANCES
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.4382470	total: 16.5ms	remaining: 16.5s
# 500:	learn: 0.3351589	total: 10.8s	remaining: 10.7s
# 999:	learn: 0.3244990	total: 19.3s	remaining: 0us
#
# Training model for family: HOME CARE
#
# Data size: (43740, 46)
#
# Learning rate set to 0.066262
# 0:	learn: 1.0570578	total: 28.1ms	remaining: 28s
# 500:	learn: 0.1562216	total: 17.8s	remaining: 17.7s
# 999:	learn: 0.1456641	total: 34.6s	remaining: 0us
#
# Training model for family: LADIESWEAR
#
# Data size: (43740, 46)
#
# Learning rate set to 0.066262
# 0:	learn: 1.3261952	total: 27.7ms	remaining: 27.7s
# 500:	learn: 0.4181917	total: 17.1s	remaining: 17s
# 999:	learn: 0.4068128	total: 36.4s	remaining: 0us
#
# Training model for family: LAWN AND GARDEN
#
# Data size: (16308, 46)
#
# Learning rate set to 0.058229
# 0:	learn: 1.4413197	total: 24.9ms	remaining: 24.9s
# 500:	learn: 0.4237125	total: 15.2s	remaining: 15.2s
# 999:	learn: 0.4080838	total: 29.8s	remaining: 0us
#
# Training model for family: LINGERIE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 0.9587349	total: 17.1ms	remaining: 17s
# 500:	learn: 0.5751882	total: 10.5s	remaining: 10.5s
# 999:	learn: 0.5609561	total: 21.6s	remaining: 0us
#
# Training model for family: LIQUOR,WINE,BEER
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.7607573	total: 17.9ms	remaining: 17.9s
# 500:	learn: 0.4706275	total: 11.5s	remaining: 11.5s
# 999:	learn: 0.4425852	total: 20.2s	remaining: 0us
#
# Training model for family: MAGAZINES
#
# Data size: (31968, 46)
#
# Learning rate set to 0.063596
# 0:	learn: 0.9767422	total: 27ms	remaining: 26.9s
# 500:	learn: 0.4624663	total: 18.1s	remaining: 18s
# 999:	learn: 0.4532369	total: 34.3s	remaining: 0us
#
# Training model for family: MEATS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.6231774	total: 17.1ms	remaining: 17.1s
# 500:	learn: 0.1993199	total: 10.9s	remaining: 10.8s
# 999:	learn: 0.1850820	total: 21.6s	remaining: 0us
#
# Training model for family: PERSONAL CARE
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.5182490	total: 17.9ms	remaining: 17.9s
# 500:	learn: 0.1800816	total: 8.64s	remaining: 8.6s
# 999:	learn: 0.1663639	total: 19.5s	remaining: 0us
#
# Training model for family: PET SUPPLIES
#
# Data size: (43740, 46)
#
# Learning rate set to 0.066262
# 0:	learn: 1.0447873	total: 28ms	remaining: 28s
# 500:	learn: 0.4409226	total: 18.6s	remaining: 18.6s
# 999:	learn: 0.4342211	total: 35.4s	remaining: 0us
#
# Training model for family: PLAYERS AND ELECTRONICS
#
# Data size: (43740, 46)
#
# Learning rate set to 0.066262
# 0:	learn: 0.9064249	total: 27.6ms	remaining: 27.6s
# 500:	learn: 0.4584311	total: 17s	remaining: 16.9s
# 999:	learn: 0.4516996	total: 36.7s	remaining: 0us
#
# Training model for family: POULTRY
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.6498515	total: 16.8ms	remaining: 16.8s
# 500:	learn: 0.2124508	total: 10.9s	remaining: 10.9s
# 999:	learn: 0.1979541	total: 19.8s	remaining: 0us
#
# Training model for family: PREPARED FOODS
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.3758062	total: 53.3ms	remaining: 53.2s
# 500:	learn: 0.2588735	total: 10.8s	remaining: 10.8s
# 999:	learn: 0.2472179	total: 21.9s	remaining: 0us
#
# Training model for family: PRODUCE
#
# Data size: (43740, 46)
#
# Learning rate set to 0.066262
# 0:	learn: 1.5189960	total: 28.7ms	remaining: 28.7s
# 500:	learn: 0.1449558	total: 15.7s	remaining: 15.7s
# 999:	learn: 0.1363271	total: 34.5s	remaining: 0us
#
# Training model for family: SCHOOL AND OFFICE SUPPLIES
#
# Data size: (43740, 46)
#
# Learning rate set to 0.066262
# 0:	learn: 0.9867240	total: 28.5ms	remaining: 28.5s
# 500:	learn: 0.4296875	total: 16.4s	remaining: 16.3s
# 999:	learn: 0.4211864	total: 32.7s	remaining: 0us
#
# Training model for family: SEAFOOD
#
# Data size: (91908, 46)
#
# Learning rate set to 0.073032
# 0:	learn: 1.4198287	total: 16.9ms	remaining: 16.9s
# 500:	learn: 0.4376160	total: 11.1s	remaining: 11.1s
# 999:	learn: 0.4213962	total: 22.4s	remaining: 0us
# Loss on 2017-08-01 00:00:00: 0.36580976021088507
# Loss on 2017-08-02 00:00:00: 0.3712616720614063
# Loss on 2017-08-03 00:00:00: 0.37652283770408956
# Loss on 2017-08-04 00:00:00: 0.40213809055834393
# Loss on 2017-08-05 00:00:00: 0.3570929654538729
# Loss on 2017-08-06 00:00:00: 0.3777813591927291
# Loss on 2017-08-07 00:00:00: 0.3786071527283302
# Loss on 2017-08-08 00:00:00: 0.4089431675088065
# Loss on 2017-08-09 00:00:00: 0.3720780051844959
# Loss on 2017-08-10 00:00:00: 0.3845185452947993
# Loss on 2017-08-11 00:00:00: 0.3998733546011584
# Loss on 2017-08-12 00:00:00: 0.4033867342382782
# Loss on 2017-08-13 00:00:00: 0.39693830693366555
# Loss on 2017-08-14 00:00:00: 0.40851989537526967
# Loss on 2017-08-15 00:00:00: 0.4024970030188493
# Common loss: 0.3870645900043321

# %% [markdown]
# # In general, the 33-model approach is the best.
